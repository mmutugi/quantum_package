# %%
##rpt2 convergence

import matplotlib.pyplot as plt

rpt2_6 = [
-2.32E-01,
-2.22E-01,
-2.10E-01,
-2.04E-01,
-1.94E-01,
-1.81E-01,
-1.66E-01,
-1.48E-01,
-1.26E-01,
-9.87E-02,
-6.81E-02,
-3.54E-02,
-2.07E-02,
-1.80E-02,
-1.68E-02,
-1.59E-02,
-1.54E-02,
-1.37E-02,
-1.18E-02,
-1.02E-02,
-8.61E-03,
-7.07E-03,
-5.52E-03
]
n_det_6 = [
1,
9,
23,
49,
103,
209,
421,
847,
1698,
3397,
6798,
13600,
25005,
50039,
100108,
200251,
400515,
801058,
1602144,
3204301,
6408604,
12817236,
25634473
]

rpt2_8 = [
-2.436664E-01,
-2.346220E-01,
-2.196725E-01,
-2.113378E-01,
-2.022296E-01,
-1.899884E-01,
-1.742243E-01,
-1.581728E-01,
-1.412112E-01,
-1.178868E-01,
-9.168212E-02,
-5.918526E-02,
-3.221266E-02,
-2.687247E-02,
-2.532432E-02,
-2.436524E-02,
-2.288401E-02,
-2.014298E-02,
-1.737787E-02,
-1.497702E-02,
-1.290810E-02,
-1.087874E-02,
-8.902160E-03
]

n_det_8 = [
1,
9,
23,
50,
102,
205,
411,
824,
1651,
3303,
6608,
13221,
26444,
52896,
105804,
211611,
423228,
846459,
1692942,
3385891,
6771809,
13543625,
27087296,
]
rpt2_1 = [
-2.4669630E-01,
-2.4095690E-01,
-2.2839410E-01,
-2.2104220E-01,
-2.0770310E-01,
-1.9296880E-01,
-1.7587710E-01,
-1.5835780E-01,
-1.4093630E-01,
-1.2134570E-01,
-9.7384830E-02,
-7.1689680E-02,
-4.5730920E-02,
-3.7385830E-02,
-3.5196530E-02,
-3.3793980E-02,
-3.1656540E-02,
-2.8143490E-02,
-2.4556530E-02,
-2.1127850E-02,
-1.7940320E-02,
-1.5053360E-02,
-1.2339160E-02
]

n_det_1 = [
 1,
9,
23,
49,
99,
202,
406,
818,
1638,
3276,
6556,
13117,
25794,
51595,
103230,
206510,
413061,
826157,
1652321,
3304652,
6609323,
13218648,
26437346,
]

rpt2_1_8 = [
-2.680827E-01,
-2.686927E-01,
-2.694767E-01,
-2.719887E-01,
-2.635498E-01,
-2.448844E-01,
-2.182945E-01,
-1.988358E-01,
-1.901698E-01,
-1.816060E-01,
-1.704955E-01,
-1.564455E-01,
-1.396098E-01,
-1.216468E-01,
-1.092346E-01,
-9.925434E-02,
-8.969659E-02,
-8.010870E-02,
-7.020049E-02,
-6.271743E-02,
-5.487298E-02,
-4.855121E-02,
-4.270647E-02,
-3.777571E-02
]
n_det_1_8 = [
    1,
4,
10,
24,
54,
109,
220,
443,
891,
1813,
3630,
7264,
14596,
29232,
58465,
117436,
234887,
470579,
941621,
1883279,
3766602,
7533603,
15068049,
30139075,
]
rpt2_2 = [
-2.7439440E-01,
-2.7617850E-01,
-2.8115120E-01,
-2.8049150E-01,
-2.6279230E-01,
-2.4613170E-01,
-2.2046330E-01,
-2.0493090E-01,
-2.0261510E-01,
-1.9220520E-01,
-1.7991570E-01,
-1.6050340E-01,
-1.4420740E-01,
-1.2764900E-01,
-1.1770070E-01,
-1.0591420E-01,
-9.3997130E-02,
-8.0664640E-02,
-7.0062840E-02,
-6.1061290E-02,
-5.1121050E-02,
-4.3292120E-02,
-3.6535620E-02,
-3.0941970E-02
]

n_det_2= [
1,
9,
18,
42,
84,
171,
343,
689,
1429,
2901,
5803,
11608,
23278,
46763,
93532,
187072,
374927,
750183,
1500961,
3001945,
6004418,
12008951,
24018015,
48037118
]

rpt2_1_6 = [
-2.6073320E-01,
-2.6193590E-01,
-2.5920560E-01,
-2.5526550E-01,
-2.3455380E-01,
-2.0941130E-01,
-1.9284720E-01,
-1.7780540E-01,
-1.6839430E-01,
-1.5167990E-01,
-1.3288400E-01,
-1.1652680E-01,
-9.8951070E-02,
-8.7093680E-02,
-8.1339190E-02,
-7.7184800E-02,
-7.0940380E-02,
-6.4036160E-02,
-5.6770110E-02,
-5.0150680E-02,
-4.4415230E-02,
-3.9119470E-02,
-3.4128760E-02
]

n_det_1_6 = [
    1,
9,
23,
50,
104,
212,
426,
858,
1731,
3463,
6930,
13862,
27781,
55564,
111178,
222358,
444750,
889649,
1779309,
3559471,
7118961,
14237941,
28476429,
]

rpt2_1_4 = [
-2.540703E-01,
-2.537797E-01,
-2.479393E-01,
-2.434109E-01,
-2.283694E-01,
-2.074752E-01,
-1.924169E-01,
-1.767663E-01,
-1.552240E-01,
-1.353536E-01,
-1.166979E-01,
-9.610532E-02,
-8.010348E-02,
-6.827138E-02,
-6.397364E-02,
-6.076634E-02,
-5.661752E-02,
-5.118298E-02,
-4.535084E-02,
-3.966712E-02,
-3.430490E-02,
-2.939425E-02,
-2.519441E-02
]

n_det_1_4 = [
    1,
9,
23,
46,
98,
196,
396,
794,
1611,
3255,
6513,
13027,
26059,
52126,
104254,
208543,
417152,
834322,
1668660,
3337366,
6674745,
13349510,
26699041,

]
rpt2_1_2 = [
-0.2494675,
-0.2468528,
-0.2382079,
-0.2324125,
-0.2178973,
-0.2001991,
-0.1856325,
-0.1679215,
-0.1474644,
-0.1274443,
-0.1062905,
-0.0856506,
-0.0619059,
-0.0510889,
-0.0479706,
-0.0458604,
-0.0428306,
-0.0385434,
-0.0341164,
-0.0295181,
-0.0251944,
-0.0213082,
-0.0177028,
]

n_det_1_2 = [
1,
9,
22,
44,
90,
185,
373,
752,
1505,
3013,
6028,
12059,
24122,
48307,
96670,
193351,
386716,
773481,
1546968,
3093938,
6187895,
12375809,
24751623,
]

plt.figure(figsize=(10, 6))

# Plot each rpt2 vs n_det pair
plt.plot(n_det_6, rpt2_6, label='rpt2_6')
plt.plot(n_det_8, rpt2_8, label='rpt2_8')
plt.plot(n_det_1, rpt2_1, label='rpt2_1')
plt.plot(n_det_1_2, rpt2_1_2, label='rpt2_1.2')
plt.plot(n_det_1_4, rpt2_1_4, label='rpt2_1.4')
plt.plot(n_det_1_6, rpt2_1_6, label='rpt2_1.6')
plt.plot(n_det_1_8, rpt2_1_8, label='rpt2_1.8')
plt.plot(n_det_2, rpt2_2, label='rpt2_2', marker='o', markerfacecolor ='none', markeredgecolor = 'black', color = 'black')




# Add labels and title
plt.xlabel('n_det')
plt.xscale('log')
plt.ylabel('rpt2')
plt.title('rpt2 Convergence')

# Add legend
plt.legend()

# Show the plot
plt.grid(True)
plt.show()

plt.figure(figsize=(10, 6))

# Plot each rpt2 vs n_det pair
plt.plot( rpt2_6, n_det_6, label='rpt2_6')
plt.plot( rpt2_8, n_det_8, label='rpt2_8')
plt.plot( rpt2_1, n_det_1, label='rpt2_1')
plt.plot( rpt2_1_2,n_det_1_2,label='rpt2_1.2')
plt.plot( rpt2_1_4, n_det_1_4, label='rpt2_1.4')
plt.plot( rpt2_1_6, n_det_1_6, label='rpt2_1.6')
plt.plot( rpt2_1_8, n_det_1_8, label='rpt2_1.8')
plt.plot(rpt2_2, n_det_2, label='rpt2_2', marker='o', markerfacecolor ='none', markeredgecolor = 'black', color = 'black')




# Add labels and title
plt.xlabel('rpt2')
plt.ylabel('n_det')
plt.title('rpt2 Convergence')

# Add legend
plt.legend()

# Show the plot
plt.grid(True)
plt.show()

# %%
##0.60

import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression
from scipy.optimize import curve_fit

Energy = [
-8.53791392,
-8.55039599,
-8.56322901,
-8.57006886,
-8.58191673,
-8.59635585,
-8.61257606,
-8.63170092,
-8.65739585,
-8.68804219,
-8.72388171,
-8.76146577,
-8.77792227,
-8.78116946,
-8.78289254,
-8.78482429,
-8.78835271,
-8.79177713,
-8.79432818,
-8.79634758,
-8.79823975,
-8.80007832,
-8.8019361
]
rpt2 = [
-2.32E-01,
-2.22E-01,
-2.10E-01,
-2.04E-01,
-1.94E-01,
-1.81E-01,
-1.66E-01,
-1.48E-01,
-1.26E-01,
-9.87E-02,
-6.81E-02,
-3.54E-02,
-2.07E-02,
-1.80E-02,
-1.68E-02,
-1.59E-02,
-1.54E-02,
-1.37E-02,
-1.18E-02,
-1.02E-02,
-8.61E-03,
-7.07E-03,
-5.52E-03
]
pt2 =[
-0.25985720,
-0.24341550,
-0.22742560,
-0.21983830,
-0.20678880,
-0.19167730,
-0.17480380,
-0.15518830,
-0.13045440,
-0.10150310,
-0.06939067,
-0.03565705,
-0.02073907,
-0.01810628,
-0.01685235,
-0.01595411,
-0.01539636,
-0.01372853,
-0.01186249,
-0.01024088,
-0.00861966,
-0.00707762,
-0.00552326


]

n_det = [
1,
9,
23,
49,
103,
209,
421,
847,
1698,
3397,
6798,
13600,
25005,
50039,
100108,
200251,
400515,
801058,
1602144,
3204301,
6408604,
12817236,
25634473
]

last_points = 10
last_points1 = 4
last_points2 = 3
last_points3 = 23
determinants =np.array(n_det)
x_fit = np.array(rpt2[-last_points:]).reshape(-1, 1)
x_fit1 = np.array(rpt2[-last_points1:]).reshape(-1, 1)
x_fit2 = np.array(rpt2[-last_points2:]).reshape(-1, 1)
x_fit3 = np.array(rpt2[-last_points3:]).reshape(-1, 1)

y_fit = np.array(Energy[-last_points:])
y_fit1 = np.array(Energy[-last_points1:])
y_fit2 = np.array(Energy[-last_points2:])
y_fit3 = np.array(Energy[-last_points3:])

model = LinearRegression()
model.fit(x_fit, y_fit)
model1 = LinearRegression()
model1.fit(x_fit1, y_fit1)
model2 = LinearRegression()
model2.fit(x_fit2, y_fit2)

model3 = LinearRegression()
model3.fit(x_fit3, y_fit3)

# Calculate R^2
r_squared10 = model.score(x_fit, y_fit)
print(f'R^2;10: {r_squared10}')

r_squared4 = model1.score(x_fit1, y_fit1)
print(f'R^2;4: {r_squared4}')

r_squared3 = model2.score(x_fit2, y_fit2)
print(f'R^2;3: {r_squared3}')

r_squared6 = model3.score(x_fit3, y_fit3)
print(f'R^2;6: {r_squared6}')

# Y-value at x=0 (intercept)
y_intercept10 = model.intercept_
print(f'Y-value at x=0 10: {y_intercept10}')

y_intercept4 = model1.intercept_
print(f'Y-value at x=0 4: {y_intercept4}')

y_intercept3 = model2.intercept_
print(f'Y-value at x=0 3: {y_intercept3}')

y_intercept6 = model3.intercept_
print(f'Y-value at x=0 6: {y_intercept6}')

# Extend the fit line to min x value of -0.35
x_extended = np.linspace(-0.20, 0.0, 300).reshape(-1, 1)
y_extended = model.predict(x_extended)

x_extended1 = np.linspace(-0.20, 0.0, 300).reshape(-1, 1)
y_extended1 = model1.predict(x_extended1)

x_extended2 = np.linspace(-0.20, 0.0, 300).reshape(-1, 1)
y_extended2 = model2.predict(x_extended2)

x_extended3 = np.linspace(-0.20, 0.0, 300).reshape(-1, 1)
y_extended3 = model3.predict(x_extended3)

##non - linear plots
x_fit_quad1 = np.array(pt2[-last_points1:])
y_fit_quad1= np.array(Energy[-last_points1:])

x_fit_quad2 = np.array(pt2[-last_points2:])
y_fit_quad2= np.array(Energy[-last_points2:])

x_fit_quad3 = np.array(pt2[-last_points3:])
y_fit_quad3= np.array(Energy[-last_points3:])

def model_func(pt2, a, b, c):
    return a + (abs(c)/2) - b * pt2 - np.sqrt((c/2)**2 + (b * pt2)**2)

popt, _ = curve_fit(model_func, x_fit_quad1, y_fit_quad1)
a1, b1, c1 = popt

popt, _ = curve_fit(model_func, x_fit_quad2, y_fit_quad2)
a2, b2, c2 = popt

popt, _ = curve_fit(model_func, x_fit_quad3, y_fit_quad3)
a3, b3, c3 = popt


print(f'Fitted Non-linear Energies:\na4pts = {a1}\na3pts = {a2}\na6pts = {a3}')

x_extended_quad1 = np.linspace(-0.20, 0.0, 300)
y_extended_quad1 = model_func(x_extended_quad1, a1, b1, c1)

x_extended_quad2 = np.linspace(-0.20, 0.0, 300)
y_extended_quad2 = model_func(x_extended_quad2, a2, b2, c2)

x_extended_quad3 = np.linspace(-0.25, 0.0, 300)
y_extended_quad3 = model_func(x_extended_quad3, a3, b3, c3)

# Plotting Energy and exFCI against PT2
plt.figure(figsize=(18, 6))

plt.subplot(1,2,1)

# Plotting Energy against PT2 with the fitted line
#plt.plot(rpt2, Energy, linestyle='solid', marker='o', markerfacecolor ='none', markeredgecolor = 'black', color = 'black')

plt.plot(pt2, Energy, linestyle='solid', marker='o', markerfacecolor ='none', markeredgecolor = 'blue', color = 'black')

#plt.plot(x_extended, y_extended, label='10', linestyle='--', color='red')

#plt.plot(x_extended1, y_extended1, label='4-point extrapolation', linestyle='--', color='red')

#plt.plot(x_extended2, y_extended2, label='3-point extrapolation', linestyle='--', color='green')

#plt.plot(x_extended_quad1, y_extended_quad1, label='Non-Liear Fit-4pts', linestyle='--', color='magenta')

#plt.plot(x_extended_quad2, y_extended_quad2, label='Non-Liear Fit-3pts', linestyle='--', color='black')

plt.plot(x_extended_quad3, y_extended_quad3, label='α-1 points non-linear extrapolation', linestyle='--', color='red')

#plt.plot(x_extended3, y_extended3, label='6-point extrapolation', linestyle='--', color='blue')

#plt.axhline(y=[y_intercept3], color='black', linestyle='-', marker='o', markerfacecolor ='none', markeredgecolor = 'black', linewidth = 2.0)# label=f'{y_intercept3}')

#plt.xlim([-0.10, 0.00])
#plt.ylim([-8.40, -8.275])
plt.xlabel('$E^{pt2}$ ($E_h$)', fontsize=20)
plt.ylabel('Variational Energy $E_{0}$ ($E_h$)', fontsize=15)
plt.title('$H20$ 0.60Å', fontsize=16)
plt.legend()
plt.grid(color = 'gray', linestyle = ':', linewidth = 1.5)



plt.subplot(1,2,2)
plt.plot(rpt2, Energy, linestyle='solid', marker='o', markerfacecolor ='none', markeredgecolor = 'black', color = 'black')
plt.plot(x_extended2, y_extended2, label='3-point extrapolation', linestyle='--', color='green')

plt.xlabel('$E_{r}^{PT2}$ ($E_h$)', fontsize=20)
plt.ylabel('Variational Energy $E_{0}$ ($E_h$)', fontsize=15)
plt.title('$H20$ 0.60Å', fontsize=16)
plt.legend()
plt.grid(color = 'gray', linestyle = ':', linewidth = 1.5)
plt.tight_layout()
plt.show()
# Out:
# R^2;10: 0.964025691505074
# R^2;4: 0.9999974123104303
# R^2;3: 0.9999987184727845
# R^2;6: 0.999422508960283
# Y-value at x=0 10: -8.81261538716102
# Y-value at x=0 4: -8.808524064459647
# Y-value at x=0 3: -8.808538098279456
# Y-value at x=0 6: -8.805168739541937
# Fitted Non-linear Energies:
# a4pts = -8.808741800382604
# a3pts = -8.808574255887773
# a6pts = -8.807408316225327
# /opt/anaconda3/lib/python3.11/site-packages/scipy/optimize/_minpack_py.py:1010: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',

# %%
###0.60

Energy = [
-8.53791392,
-8.55039599,
-8.56322901,
-8.57006886,
-8.58191673,
-8.59635585,
-8.61257606,
-8.63170092,
-8.65739585,
-8.68804219,
-8.72388171,
-8.76146577,
-8.77792227,
-8.78116946,
-8.78289254,
-8.78482429,
-8.78835271,
-8.79177713,
-8.79432818,
-8.79634758,
-8.79823975,
-8.80007832,
-8.8019361
]
rpt2 = [
-2.32E-01,
-2.22E-01,
-2.10E-01,
-2.04E-01,
-1.94E-01,
-1.81E-01,
-1.66E-01,
-1.48E-01,
-1.26E-01,
-9.87E-02,
-6.81E-02,
-3.54E-02,
-2.07E-02,
-1.80E-02,
-1.68E-02,
-1.59E-02,
-1.54E-02,
-1.37E-02,
-1.18E-02,
-1.02E-02,
-8.61E-03,
-7.07E-03,
-5.52E-03
]
def regression_intercept_and_error(x, y):
    model = LinearRegression()
    model.fit(x, y)

    # Predicted values
    y_pred = model.predict(x)

    # Residuals
    residuals = y - y_pred

    # Degrees of freedom
    dof = len(y) - 2

    # Residual standard error
    residual_std_error = np.sqrt(np.sum(residuals**2) / dof)

    # Standard error of intercept
    x_mean = np.mean(x)
    x_diff_sq_sum = np.sum((x - x_mean) ** 2)
    intercept_std_error = residual_std_error * np.sqrt(np.sum(x ** 2) / (len(y) * x_diff_sq_sum))

    return model.intercept_, intercept_std_error

# Only using points from 3 to 6
points_to_fit = range(3, 7)

intercept_estimates = []
intercept_errors = []

for points in points_to_fit:
    x_fit = np.array(rpt2[-points:]).reshape(-1, 1)
    y_fit = np.array(Energy[-points:])
    
    intercept, intercept_error = regression_intercept_and_error(x_fit, y_fit)
    intercept_estimates.append(intercept)
    intercept_errors.append(intercept_error)
    
    # Print the intercept and its error
    print(f"Points used: {points}, Intercept: {intercept}, Error: {intercept_error}")

# Plotting intercept estimate with error bars
plt.figure(figsize=(8, 6))

plt.errorbar(points_to_fit, intercept_estimates, yerr=intercept_errors, fmt='o', color='blue', ecolor='red', capsize=5, label='exFCI')

plt.xlabel('Number of Points Used in Fit', fontsize=14)
plt.ylabel('exFCI', fontsize=14)
plt.title('exFCI errors as a Function of Number of Points 2.00Å', fontsize=16)
plt.grid(True)
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Points used: 3, Intercept: -8.808538098279456, Error: 9.720892497230514e-06
# Points used: 4, Intercept: -8.808524064459647, Error: 1.0921616739393233e-05
# Points used: 5, Intercept: -8.808620045112407, Error: 6.918054023540845e-05
# Points used: 6, Intercept: -8.808829799641373, Error: 0.00015306881528897266

# %%
##0.80
Energy = [
-10.3437060500,
-10.3585273900,
-10.3775368200,
-10.3908620900,
-10.4006520800,
-10.4158219600,
-10.4354439200,
-10.4544577100,
-10.4750622800,
-10.5033091900,
-10.5359385500,
-10.5743442700,
-10.6061010400,
-10.6129887000,
-10.6159412600,
-10.6196005100,
-10.6255695100,
-10.6308268100,
-10.6348739400,
-10.6379809300,
-10.6407361300,
-10.6433934000,
-10.6459792400
]
rpt2 = [
-2.436664E-01,
-2.346220E-01,
-2.196725E-01,
-2.113378E-01,
-2.022296E-01,
-1.899884E-01,
-1.742243E-01,
-1.581728E-01,
-1.412112E-01,
-1.178868E-01,
-9.168212E-02,
-5.918526E-02,
-3.221266E-02,
-2.687247E-02,
-2.532432E-02,
-2.436524E-02,
-2.288401E-02,
-2.014298E-02,
-1.737787E-02,
-1.497702E-02,
-1.290810E-02,
-1.087874E-02,
-8.902160E-03
]
pt2 =[
-0.2888413,
-0.2698038,
-0.2460132,
-0.2330729,
-0.2210517,
-0.2054964,
-0.1863583,
-0.1675950,
-0.1484679,
-0.1226732,
-0.0943847,
-0.0602238,
-0.0324778,
-0.0270410,
-0.0254699,
-0.0244975,
-0.0229970,
-0.0202262,
-0.0174371,
-0.0150194,
-0.0129386,
-0.0108996,
-0.0089157,
]

n_det = [
1,
9,
23,
50,
102,
205,
411,
824,
1651,
3303,
6608,
13221,
26444,
52896,
105804,
211611,
423228,
846459,
1692942,
3385891,
6771809,
13543625,
27087296,
]

last_points = 10
last_points1 = 4
last_points2 = 3
last_points3 = 23
determinants =np.array(n_det)
x_fit = np.array(rpt2[-last_points:]).reshape(-1, 1)
x_fit1 = np.array(rpt2[-last_points1:]).reshape(-1, 1)
x_fit2 = np.array(rpt2[-last_points2:]).reshape(-1, 1)
x_fit3 = np.array(rpt2[-last_points3:]).reshape(-1, 1)

y_fit = np.array(Energy[-last_points:])
y_fit1 = np.array(Energy[-last_points1:])
y_fit2 = np.array(Energy[-last_points2:])
y_fit3 = np.array(Energy[-last_points3:])

model = LinearRegression()
model.fit(x_fit, y_fit)
model1 = LinearRegression()
model1.fit(x_fit1, y_fit1)
model2 = LinearRegression()
model2.fit(x_fit2, y_fit2)

model3 = LinearRegression()
model3.fit(x_fit3, y_fit3)

# Calculate R^2
r_squared10 = model.score(x_fit, y_fit)
print(f'R^2;10: {r_squared10}')

r_squared4 = model1.score(x_fit1, y_fit1)
print(f'R^2;4: {r_squared4}')

r_squared3 = model2.score(x_fit2, y_fit2)
print(f'R^2;3: {r_squared3}')

r_squared6 = model3.score(x_fit3, y_fit3)
print(f'R^2;6: {r_squared6}')

# Y-value at x=0 (intercept)
y_intercept10 = model.intercept_
print(f'Y-value at x=0 10: {y_intercept10}')

y_intercept4 = model1.intercept_
print(f'Y-value at x=0 4: {y_intercept4}')

y_intercept3 = model2.intercept_
print(f'Y-value at x=0 3: {y_intercept3}')

y_intercept6 = model3.intercept_
print(f'Y-value at x=0 6: {y_intercept6}')

# Extend the fit line to min x value of -0.35
x_extended = np.linspace(-0.20, 0.0, 300).reshape(-1, 1)
y_extended = model.predict(x_extended)

x_extended1 = np.linspace(-0.20, 0.0, 300).reshape(-1, 1)
y_extended1 = model1.predict(x_extended1)

x_extended2 = np.linspace(-0.20, 0.0, 300).reshape(-1, 1)
y_extended2 = model2.predict(x_extended2)

x_extended3 = np.linspace(-0.20, 0.0, 300).reshape(-1, 1)
y_extended3 = model3.predict(x_extended3)

##non - linear plots
x_fit_quad1 = np.array(pt2[-last_points1:])
y_fit_quad1= np.array(Energy[-last_points1:])

x_fit_quad2 = np.array(pt2[-last_points2:])
y_fit_quad2= np.array(Energy[-last_points2:])

x_fit_quad3 = np.array(pt2[-last_points3:])
y_fit_quad3= np.array(Energy[-last_points3:])

def model_func(pt2, a, b, c):
    return a + (abs(c)/2) - b * pt2 - np.sqrt((c/2)**2 + (b * pt2)**2)

popt, _ = curve_fit(model_func, x_fit_quad1, y_fit_quad1)
a1, b1, c1 = popt

popt, _ = curve_fit(model_func, x_fit_quad2, y_fit_quad2)
a2, b2, c2 = popt

popt, _ = curve_fit(model_func, x_fit_quad3, y_fit_quad3)
a3, b3, c3 = popt


print(f'Fitted Non-linear Energies:\na4pts = {a1}\na3pts = {a2}\na6pts = {a3}')

x_extended_quad1 = np.linspace(-0.20, 0.0, 300)
y_extended_quad1 = model_func(x_extended_quad1, a1, b1, c1)

x_extended_quad2 = np.linspace(-0.20, 0.0, 300)
y_extended_quad2 = model_func(x_extended_quad2, a2, b2, c2)

x_extended_quad3 = np.linspace(-0.25, 0.0, 300)
y_extended_quad3 = model_func(x_extended_quad3, a3, b3, c3)

# Plotting Energy and exFCI against PT2
plt.figure(figsize=(18, 6))

plt.subplot(1,2,1)

# Plotting Energy against PT2 with the fitted line
#plt.plot(rpt2, Energy, linestyle='solid', marker='o', markerfacecolor ='none', markeredgecolor = 'black', color = 'black')

plt.plot(pt2, Energy, linestyle='solid', marker='o', markerfacecolor ='none', markeredgecolor = 'blue', color = 'black')

#plt.plot(x_extended, y_extended, label='10', linestyle='--', color='red')

#plt.plot(x_extended1, y_extended1, label='4-point extrapolation', linestyle='--', color='red')

#plt.plot(x_extended2, y_extended2, label='3-point extrapolation', linestyle='--', color='green')

#plt.plot(x_extended_quad1, y_extended_quad1, label='Non-Liear Fit-4pts', linestyle='--', color='magenta')

#plt.plot(x_extended_quad2, y_extended_quad2, label='Non-Liear Fit-3pts', linestyle='--', color='black')

plt.plot(x_extended_quad3, y_extended_quad3, label='α-1 points non-linear extrapolation', linestyle='--', color='red')

#plt.plot(x_extended3, y_extended3, label='6-point extrapolation', linestyle='--', color='blue')

#plt.axhline(y=[y_intercept3], color='black', linestyle='-', marker='o', markerfacecolor ='none', markeredgecolor = 'black', linewidth = 2.0)# label=f'{y_intercept3}')

#plt.xlim([-0.10, 0.00])
#plt.ylim([-8.40, -8.275])
plt.xlabel('$E^{pt2}$ ($E_h$)', fontsize=20)
plt.ylabel('Variational Energy $E_{0}$ ($E_h$)', fontsize=15)
plt.title('$H20$ 0.80Å', fontsize=16)
plt.legend()
plt.grid(color = 'gray', linestyle = ':', linewidth = 1.5)



plt.subplot(1,2,2)
plt.plot(rpt2, Energy, linestyle='solid', marker='o', markerfacecolor ='none', markeredgecolor = 'black', color = 'black')
plt.plot(x_extended2, y_extended2, label='3-point extrapolation', linestyle='--', color='green')

plt.xlabel('$E_{r}^{PT2}$ ($E_h$)', fontsize=20)
plt.ylabel('Variational Energy $E_{0}$ ($E_h$)', fontsize=15)
plt.title('$H20$ 0.80Å', fontsize=16)
plt.legend()
plt.grid(color = 'gray', linestyle = ':', linewidth = 1.5)
plt.tight_layout()
plt.show()
# Out:
# R^2;10: 0.9670743176964702
# R^2;4: 0.999981176664512
# R^2;3: 0.9999999330591405
# R^2;6: 0.9990266676005343
# Y-value at x=0 10: -10.664202927131399
# Y-value at x=0 4: -10.657704002502797
# Y-value at x=0 3: -10.657631108321086
# Y-value at x=0 6: -10.653030277283559
# Fitted Non-linear Energies:
# a4pts = -10.657665819755719
# a3pts = -10.657604672065688
# a6pts = -10.655957489489493
# /opt/anaconda3/lib/python3.11/site-packages/scipy/optimize/_minpack_py.py:1010: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',

# %%
##0.80
Energy = [
-10.3437060500,
-10.3585273900,
-10.3775368200,
-10.3908620900,
-10.4006520800,
-10.4158219600,
-10.4354439200,
-10.4544577100,
-10.4750622800,
-10.5033091900,
-10.5359385500,
-10.5743442700,
-10.6061010400,
-10.6129887000,
-10.6159412600,
-10.6196005100,
-10.6255695100,
-10.6308268100,
-10.6348739400,
-10.6379809300,
-10.6407361300,
-10.6433934000,
-10.6459792400
]
rpt2 = [
-2.436664E-01,
-2.346220E-01,
-2.196725E-01,
-2.113378E-01,
-2.022296E-01,
-1.899884E-01,
-1.742243E-01,
-1.581728E-01,
-1.412112E-01,
-1.178868E-01,
-9.168212E-02,
-5.918526E-02,
-3.221266E-02,
-2.687247E-02,
-2.532432E-02,
-2.436524E-02,
-2.288401E-02,
-2.014298E-02,
-1.737787E-02,
-1.497702E-02,
-1.290810E-02,
-1.087874E-02,
-8.902160E-03
]

def regression_intercept_and_error(x, y):
    model = LinearRegression()
    model.fit(x, y)

    # Predicted values
    y_pred = model.predict(x)

    # Residuals
    residuals = y - y_pred

    # Degrees of freedom
    dof = len(y) - 2

    # Residual standard error
    residual_std_error = np.sqrt(np.sum(residuals**2) / dof)

    # Standard error of intercept
    x_mean = np.mean(x)
    x_diff_sq_sum = np.sum((x - x_mean) ** 2)
    intercept_std_error = residual_std_error * np.sqrt(np.sum(x ** 2) / (len(y) * x_diff_sq_sum))

    return model.intercept_, intercept_std_error

# Only using points from 3 to 6
points_to_fit = range(3, 7)

intercept_estimates = []
intercept_errors = []

for points in points_to_fit:
    x_fit = np.array(rpt2[-points:]).reshape(-1, 1)
    y_fit = np.array(Energy[-points:])
    
    intercept, intercept_error = regression_intercept_and_error(x_fit, y_fit)
    intercept_estimates.append(intercept)
    intercept_errors.append(intercept_error)
    
    # Print the intercept and its error
    print(f"Points used: {points}, Intercept: {intercept}, Error: {intercept_error}")

# Plotting intercept estimate with error bars
plt.figure(figsize=(8, 6))

plt.errorbar(points_to_fit, intercept_estimates, yerr=intercept_errors, fmt='o', color='blue', ecolor='red', capsize=5, label='exFCI')

plt.xlabel('Number of Points Used in Fit', fontsize=14)
plt.ylabel('exFCI', fontsize=14)
plt.title('exFCI errors as a Function of Number of Points 0.80Å', fontsize=16)
plt.grid(True)
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Points used: 3, Intercept: -10.657631108321086, Error: 3.7312042085202285e-06
# Points used: 4, Intercept: -10.657704002502797, Error: 4.897009175920205e-05
# Points used: 5, Intercept: -10.657662474006436, Error: 4.031190578538365e-05
# Points used: 6, Intercept: -10.657988562914888, Error: 0.00021016090935151266

# %%
##1.00
Energy = [
-10.657946760,
-10.672272270,
-10.692438380,
-10.703532650,
-10.720437000,
-10.744128760,
-10.766698180,
-10.789537130,
-10.814111890,
-10.839947680,
-10.870835630,
-10.903206510,
-10.934643770,
-10.946349930,
-10.951279580,
-10.956567940,
-10.964021540,
-10.970782640,
-10.977092470,
-10.982411940,
-10.987052210,
-10.991186800,
-10.995045660
]
rpt2 = [
-2.4669630E-01,
-2.4095690E-01,
-2.2839410E-01,
-2.2104220E-01,
-2.0770310E-01,
-1.9296880E-01,
-1.7587710E-01,
-1.5835780E-01,
-1.4093630E-01,
-1.2134570E-01,
-9.7384830E-02,
-7.1689680E-02,
-4.5730920E-02,
-3.7385830E-02,
-3.5196530E-02,
-3.3793980E-02,
-3.1656540E-02,
-2.8143490E-02,
-2.4556530E-02,
-2.1127850E-02,
-1.7940320E-02,
-1.5053360E-02,
-1.2339160E-02
]

pt2 = [
-0.3115906,
-0.2938126,
-0.2686548,
-0.2559459,
-0.2362510,
-0.2135931,
-0.1917744,
-0.1700160,
-0.1494139,
-0.1272053,
-0.1009232,
-0.0734732,
-0.0464001,
-0.0377951,
-0.0355445,
-0.0341062,
-0.0319216,
-0.0283441,
-0.0247024,
-0.0212311,
-0.0180116,
-0.0151015,
-0.0123702,


]

n_det = [
 1,
9,
23,
49,
99,
202,
406,
818,
1638,
3276,
6556,
13117,
25794,
51595,
103230,
206510,
413061,
826157,
1652321,
3304652,
6609323,
13218648,
26437346,

]


last_points = 10
last_points1 = 4
last_points2 = 3
last_points3 = 23
determinants =np.array(n_det)
x_fit = np.array(rpt2[-last_points:]).reshape(-1, 1)
x_fit1 = np.array(rpt2[-last_points1:]).reshape(-1, 1)
x_fit2 = np.array(rpt2[-last_points2:]).reshape(-1, 1)
x_fit3 = np.array(rpt2[-last_points3:]).reshape(-1, 1)

y_fit = np.array(Energy[-last_points:])
y_fit1 = np.array(Energy[-last_points1:])
y_fit2 = np.array(Energy[-last_points2:])
y_fit3 = np.array(Energy[-last_points3:])

model = LinearRegression()
model.fit(x_fit, y_fit)
model1 = LinearRegression()
model1.fit(x_fit1, y_fit1)
model2 = LinearRegression()
model2.fit(x_fit2, y_fit2)

model3 = LinearRegression()
model3.fit(x_fit3, y_fit3)

# Calculate R^2
r_squared10 = model.score(x_fit, y_fit)
print(f'R^2;10: {r_squared10}')

r_squared4 = model1.score(x_fit1, y_fit1)
print(f'R^2;4: {r_squared4}')

r_squared3 = model2.score(x_fit2, y_fit2)
print(f'R^2;3: {r_squared3}')

r_squared6 = model3.score(x_fit3, y_fit3)
print(f'R^2;6: {r_squared6}')

# Y-value at x=0 (intercept)
y_intercept10 = model.intercept_
print(f'Y-value at x=0 10: {y_intercept10}')

y_intercept4 = model1.intercept_
print(f'Y-value at x=0 4: {y_intercept4}')

y_intercept3 = model2.intercept_
print(f'Y-value at x=0 3: {y_intercept3}')

y_intercept6 = model3.intercept_
print(f'Y-value at x=0 6: {y_intercept6}')

# Extend the fit line to min x value of -0.35
x_extended = np.linspace(-0.20, 0.0, 300).reshape(-1, 1)
y_extended = model.predict(x_extended)

x_extended1 = np.linspace(-0.20, 0.0, 300).reshape(-1, 1)
y_extended1 = model1.predict(x_extended1)

x_extended2 = np.linspace(-0.20, 0.0, 300).reshape(-1, 1)
y_extended2 = model2.predict(x_extended2)

x_extended3 = np.linspace(-0.20, 0.0, 300).reshape(-1, 1)
y_extended3 = model3.predict(x_extended3)

##non - linear plots
x_fit_quad1 = np.array(pt2[-last_points1:])
y_fit_quad1= np.array(Energy[-last_points1:])

x_fit_quad2 = np.array(pt2[-last_points2:])
y_fit_quad2= np.array(Energy[-last_points2:])

x_fit_quad3 = np.array(pt2[-last_points3:])
y_fit_quad3= np.array(Energy[-last_points3:])

def model_func(pt2, a, b, c):
    return a + (abs(c)/2) - b * pt2 - np.sqrt((c/2)**2 + (b * pt2)**2)

popt, _ = curve_fit(model_func, x_fit_quad1, y_fit_quad1)
a1, b1, c1 = popt

popt, _ = curve_fit(model_func, x_fit_quad2, y_fit_quad2)
a2, b2, c2 = popt

popt, _ = curve_fit(model_func, x_fit_quad3, y_fit_quad3)
a3, b3, c3 = popt


print(f'Fitted Non-linear Energies:\na4pts = {a1}\na3pts = {a2}\na6pts = {a3}')

x_extended_quad1 = np.linspace(-0.20, 0.0, 300)
y_extended_quad1 = model_func(x_extended_quad1, a1, b1, c1)

x_extended_quad2 = np.linspace(-0.20, 0.0, 300)
y_extended_quad2 = model_func(x_extended_quad2, a2, b2, c2)

x_extended_quad3 = np.linspace(-0.30, 0.0, 300)
y_extended_quad3 = model_func(x_extended_quad3, a3, b3, c3)

# Plotting Energy and exFCI against PT2
plt.figure(figsize=(18, 6))

plt.subplot(1,2,1)

# Plotting Energy against PT2 with the fitted line
#plt.plot(rpt2, Energy, linestyle='solid', marker='o', markerfacecolor ='none', markeredgecolor = 'black', color = 'black')

plt.plot(pt2, Energy, linestyle='solid', marker='o', markerfacecolor ='none', markeredgecolor = 'blue', color = 'black')

#plt.plot(x_extended, y_extended, label='10', linestyle='--', color='red')

#plt.plot(x_extended1, y_extended1, label='4-point extrapolation', linestyle='--', color='red')

#plt.plot(x_extended2, y_extended2, label='3-point extrapolation', linestyle='--', color='green')

#plt.plot(x_extended_quad1, y_extended_quad1, label='Non-Liear Fit-4pts', linestyle='--', color='magenta')

#plt.plot(x_extended_quad2, y_extended_quad2, label='Non-Liear Fit-3pts', linestyle='--', color='black')

plt.plot(x_extended_quad3, y_extended_quad3, label='α-1 points non-linear extrapolation', linestyle='--', color='red')

#plt.plot(x_extended3, y_extended3, label='6-point extrapolation', linestyle='--', color='blue')

#plt.axhline(y=[y_intercept3], color='black', linestyle='-', marker='o', markerfacecolor ='none', markeredgecolor = 'black', linewidth = 2.0)# label=f'{y_intercept3}')

#plt.xlim([-0.10, 0.00])
#plt.ylim([-8.40, -8.275])
plt.xlabel('$E^{pt2}$ ($E_h$)', fontsize=20)
plt.ylabel('Variational Energy $E_{0}$ ($E_h$)', fontsize=15)
plt.title('$H20$ 1.00Å', fontsize=16)
plt.legend()
plt.grid(color = 'gray', linestyle = ':', linewidth = 1.5)



plt.subplot(1,2,2)
plt.plot(rpt2, Energy, linestyle='solid', marker='o', markerfacecolor ='none', markeredgecolor = 'black', color = 'black')
plt.plot(x_extended2, y_extended2, label='3-point extrapolation', linestyle='--', color='green')

plt.xlabel('$E_{r}^{PT2}$ ($E_h$)', fontsize=20)
plt.ylabel('Variational Energy $E_{0}$ ($E_h$)', fontsize=15)
plt.title('$H20$ 1.00Å', fontsize=16)
plt.legend()
plt.grid(color = 'gray', linestyle = ':', linewidth = 1.5)
plt.tight_layout()
plt.show()
# Out:
# R^2;10: 0.9775488499929929
# R^2;4: 0.9999698725634242
# R^2;3: 0.9999955601910651
# R^2;6: 0.9984920846351092
# Y-value at x=0 10: -11.021379550907056
# Y-value at x=0 4: -11.012804431313398
# Y-value at x=0 3: -11.012660624428289
# Y-value at x=0 6: -11.007162283763359
# Fitted Non-linear Energies:
# a4pts = -11.012700356769324
# a3pts = -11.012580358623772
# a6pts = -11.011046188690505
# /opt/anaconda3/lib/python3.11/site-packages/scipy/optimize/_minpack_py.py:1010: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',

# %%
##1.00
Energy = [
-10.657946760,
-10.672272270,
-10.692438380,
-10.703532650,
-10.720437000,
-10.744128760,
-10.766698180,
-10.789537130,
-10.814111890,
-10.839947680,
-10.870835630,
-10.903206510,
-10.934643770,
-10.946349930,
-10.951279580,
-10.956567940,
-10.964021540,
-10.970782640,
-10.977092470,
-10.982411940,
-10.987052210,
-10.991186800,
-10.995045660
]
rpt2 = [
-2.4669630E-01,
-2.4095690E-01,
-2.2839410E-01,
-2.2104220E-01,
-2.0770310E-01,
-1.9296880E-01,
-1.7587710E-01,
-1.5835780E-01,
-1.4093630E-01,
-1.2134570E-01,
-9.7384830E-02,
-7.1689680E-02,
-4.5730920E-02,
-3.7385830E-02,
-3.5196530E-02,
-3.3793980E-02,
-3.1656540E-02,
-2.8143490E-02,
-2.4556530E-02,
-2.1127850E-02,
-1.7940320E-02,
-1.5053360E-02,
-1.2339160E-02
]

def regression_intercept_and_error(x, y):
    model = LinearRegression()
    model.fit(x, y)

    # Predicted values
    y_pred = model.predict(x)

    # Residuals
    residuals = y - y_pred

    # Degrees of freedom
    dof = len(y) - 2

    # Residual standard error
    residual_std_error = np.sqrt(np.sum(residuals**2) / dof)

    # Standard error of intercept
    x_mean = np.mean(x)
    x_diff_sq_sum = np.sum((x - x_mean) ** 2)
    intercept_std_error = residual_std_error * np.sqrt(np.sum(x ** 2) / (len(y) * x_diff_sq_sum))

    return model.intercept_, intercept_std_error

# Only using points from 3 to 6
points_to_fit = range(3, 7)

intercept_estimates = []
intercept_errors = []

for points in points_to_fit:
    x_fit = np.array(rpt2[-points:]).reshape(-1, 1)
    y_fit = np.array(Energy[-points:])
    
    intercept, intercept_error = regression_intercept_and_error(x_fit, y_fit)
    intercept_estimates.append(intercept)
    intercept_errors.append(intercept_error)
    
    # Print the intercept and its error
    print(f"Points used: {points}, Intercept: {intercept}, Error: {intercept_error}")

# Plotting intercept estimate with error bars
plt.figure(figsize=(8, 6))

plt.errorbar(points_to_fit, intercept_estimates, yerr=intercept_errors, fmt='o', color='blue', ecolor='red', capsize=5, label='exFCI')

plt.xlabel('Number of Points Used in Fit', fontsize=14)
plt.ylabel('exFCI', fontsize=14)
plt.title('exFCI errors as a Function of Number of Points 1.00Å', fontsize=16)
plt.grid(True)
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Points used: 3, Intercept: -11.012660624428289, Error: 4.595844543614207e-05
# Points used: 4, Intercept: -11.012804431313398, Error: 9.446648373437439e-05
# Points used: 5, Intercept: -11.013238881339227, Error: 0.00028909290430641444
# Points used: 6, Intercept: -11.014167417641785, Error: 0.0006546229359658825

# %%
##1.80
Energy = [
-9.56219423,
-9.56806622,
-9.57543514,
-9.5989107,
-9.63652826,
-9.68412989,
-9.73663824,
-9.77631538,
-9.80143264,
-9.8257416,
-9.85419416,
-9.88926676,
-9.93283416,
-9.97357157,
-10.000883,
-10.02382929,
-10.04775558,
-10.0727718,
-10.09760771,
-10.11841651,
-10.13884947,
-10.15723186,
-10.17410195,
-10.18919867,

]
rpt2 = [
-2.680827E-01,
-2.686927E-01,
-2.694767E-01,
-2.719887E-01,
-2.635498E-01,
-2.448844E-01,
-2.182945E-01,
-1.988358E-01,
-1.901698E-01,
-1.816060E-01,
-1.704955E-01,
-1.564455E-01,
-1.396098E-01,
-1.216468E-01,
-1.092346E-01,
-9.925434E-02,
-8.969659E-02,
-8.010870E-02,
-7.020049E-02,
-6.271743E-02,
-5.487298E-02,
-4.855121E-02,
-4.270647E-02,
-3.777571E-02
]

pt2 = [
    -0.48695080,
-0.48218650,
-0.47338320,
-0.44457430,
-0.39044230,
-0.33015450,
-0.27118600,
-0.23678710,
-0.22212960,
-0.20859610,
-0.19239000,
-0.17326590,
-0.15172160,
-0.12981070,
-0.11539480,
-0.10407340,
-0.09342800,
-0.08292359,
-0.07224464,
-0.06427393,
-0.05601229,
-0.04940744,
-0.04334542,
-0.03833469,
]

n_det = [
    1,
4,
10,
24,
54,
109,
220,
443,
891,
1813,
3630,
7264,
14596,
29232,
58465,
117436,
234887,
470579,
941621,
1883279,
3766602,
7533603,
15068049,
30139075,
]

last_points = 10
last_points1 = 4
last_points2 = 3
last_points3 = 23
determinants =np.array(n_det)
x_fit = np.array(rpt2[-last_points:]).reshape(-1, 1)
x_fit1 = np.array(rpt2[-last_points1:]).reshape(-1, 1)
x_fit2 = np.array(rpt2[-last_points2:]).reshape(-1, 1)
x_fit3 = np.array(rpt2[-last_points3:]).reshape(-1, 1)

y_fit = np.array(Energy[-last_points:])
y_fit1 = np.array(Energy[-last_points1:])
y_fit2 = np.array(Energy[-last_points2:])
y_fit3 = np.array(Energy[-last_points3:])

model = LinearRegression()
model.fit(x_fit, y_fit)
model1 = LinearRegression()
model1.fit(x_fit1, y_fit1)
model2 = LinearRegression()
model2.fit(x_fit2, y_fit2)

model3 = LinearRegression()
model3.fit(x_fit3, y_fit3)

# Calculate R^2
r_squared10 = model.score(x_fit, y_fit)
print(f'R^2;10: {r_squared10}')

r_squared4 = model1.score(x_fit1, y_fit1)
print(f'R^2;4: {r_squared4}')

r_squared3 = model2.score(x_fit2, y_fit2)
print(f'R^2;3: {r_squared3}')

r_squared6 = model3.score(x_fit3, y_fit3)
print(f'R^2;6: {r_squared6}')

# Y-value at x=0 (intercept)
y_intercept10 = model.intercept_
print(f'Y-value at x=0 10: {y_intercept10}')

y_intercept4 = model1.intercept_
print(f'Y-value at x=0 4: {y_intercept4}')

y_intercept3 = model2.intercept_
print(f'Y-value at x=0 3: {y_intercept3}')

y_intercept6 = model3.intercept_
print(f'Y-value at x=0 6: {y_intercept6}')

# Extend the fit line to min x value of -0.35
x_extended = np.linspace(-0.20, 0.0, 300).reshape(-1, 1)
y_extended = model.predict(x_extended)

x_extended1 = np.linspace(-0.20, 0.0, 300).reshape(-1, 1)
y_extended1 = model1.predict(x_extended1)

x_extended2 = np.linspace(-0.20, 0.0, 300).reshape(-1, 1)
y_extended2 = model2.predict(x_extended2)

x_extended3 = np.linspace(-0.20, 0.0, 300).reshape(-1, 1)
y_extended3 = model3.predict(x_extended3)

##non - linear plots
x_fit_quad1 = np.array(pt2[-last_points1:])
y_fit_quad1= np.array(Energy[-last_points1:])

x_fit_quad2 = np.array(pt2[-last_points2:])
y_fit_quad2= np.array(Energy[-last_points2:])

x_fit_quad3 = np.array(pt2[-last_points3:])
y_fit_quad3= np.array(Energy[-last_points3:])

def model_func(pt2, a, b, c):
    return a + (abs(c)/2) - b * pt2 - np.sqrt((c/2)**2 + (b * pt2)**2)

popt, _ = curve_fit(model_func, x_fit_quad1, y_fit_quad1)
a1, b1, c1 = popt

popt, _ = curve_fit(model_func, x_fit_quad2, y_fit_quad2)
a2, b2, c2 = popt

popt, _ = curve_fit(model_func, x_fit_quad3, y_fit_quad3)
a3, b3, c3 = popt


print(f'Fitted Non-linear Energies:\na4pts = {a1}\na3pts = {a2}\na6pts = {a3}')

x_extended_quad1 = np.linspace(-0.20, 0.0, 300)
y_extended_quad1 = model_func(x_extended_quad1, a1, b1, c1)

x_extended_quad2 = np.linspace(-0.20, 0.0, 300)
y_extended_quad2 = model_func(x_extended_quad2, a2, b2, c2)

x_extended_quad3 = np.linspace(-0.50, 0.0, 300)
y_extended_quad3 = model_func(x_extended_quad3, a3, b3, c3)

# Plotting Energy and exFCI against PT2
plt.figure(figsize=(18, 6))

plt.subplot(1,2,1)

# Plotting Energy against PT2 with the fitted line
#plt.plot(rpt2, Energy, linestyle='solid', marker='o', markerfacecolor ='none', markeredgecolor = 'black', color = 'black')

plt.plot(pt2, Energy, linestyle='solid', marker='o', markerfacecolor ='none', markeredgecolor = 'blue', color = 'black')

#plt.plot(x_extended, y_extended, label='10', linestyle='--', color='red')

#plt.plot(x_extended1, y_extended1, label='4-point extrapolation', linestyle='--', color='red')

#plt.plot(x_extended2, y_extended2, label='3-point extrapolation', linestyle='--', color='green')

#plt.plot(x_extended_quad1, y_extended_quad1, label='Non-Liear Fit-4pts', linestyle='--', color='magenta')

#plt.plot(x_extended_quad2, y_extended_quad2, label='Non-Liear Fit-3pts', linestyle='--', color='black')

plt.plot(x_extended_quad3, y_extended_quad3, label='α-1 points non-linear extrapolation', linestyle='--', color='red')

#plt.plot(x_extended3, y_extended3, label='6-point extrapolation', linestyle='--', color='blue')

#plt.axhline(y=[y_intercept3], color='black', linestyle='-', marker='o', markerfacecolor ='none', markeredgecolor = 'black', linewidth = 2.0)# label=f'{y_intercept3}')

#plt.xlim([-0.10, 0.00])
#plt.ylim([-8.40, -8.275])
plt.xlabel('$E^{pt2}$ ($E_h$)', fontsize=20)
plt.ylabel('Variational Energy $E_{0}$ ($E_h$)', fontsize=15)
plt.title('$H20$ 1.80Å', fontsize=16)
plt.legend()
plt.grid(color = 'gray', linestyle = ':', linewidth = 1.5)



plt.subplot(1,2,2)
plt.plot(rpt2, Energy, linestyle='solid', marker='o', markerfacecolor ='none', markeredgecolor = 'black', color = 'black')
plt.plot(x_extended2, y_extended2, label='3-point extrapolation', linestyle='--', color='green')

plt.xlabel('$E_{r}^{PT2}$ ($E_h$)', fontsize=20)
plt.ylabel('Variational Energy $E_{0}$ ($E_h$)', fontsize=15)
plt.title('$H20$ 1.80Å', fontsize=16)
plt.legend()
plt.grid(color = 'gray', linestyle = ':', linewidth = 1.5)
plt.tight_layout()
plt.show()
# Out:
# R^2;10: 0.9988788175665716
# R^2;4: 0.9998494041825355
# R^2;3: 0.9997139402312627
# R^2;6: 0.9967363993098136
# Y-value at x=0 10: -10.28532301385497
# Y-value at x=0 4: -10.299880726751663
# Y-value at x=0 3: -10.301002878184045
# Y-value at x=0 6: -10.279301280563981
# Fitted Non-linear Energies:
# a4pts = -10.31745956190404
# a3pts = -10.299541223387033
# a6pts = -10.30664467827156
# /opt/anaconda3/lib/python3.11/site-packages/scipy/optimize/_minpack_py.py:1010: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',

# %%
##1.80
Energy = [
-9.56219423,
-9.56806622,
-9.57543514,
-9.5989107,
-9.63652826,
-9.68412989,
-9.73663824,
-9.77631538,
-9.80143264,
-9.8257416,
-9.85419416,
-9.88926676,
-9.93283416,
-9.97357157,
-10.000883,
-10.02382929,
-10.04775558,
-10.0727718,
-10.09760771,
-10.11841651,
-10.13884947,
-10.15723186,
-10.17410195,
-10.17410195,
-10.18919867,
-10.18919866
]
rpt2 = [
-2.680827E-01,
-2.686927E-01,
-2.694767E-01,
-2.719887E-01,
-2.635498E-01,
-2.448844E-01,
-2.182945E-01,
-1.988358E-01,
-1.901698E-01,
-1.816060E-01,
-1.704955E-01,
-1.564455E-01,
-1.396098E-01,
-1.216468E-01,
-1.092346E-01,
-9.925434E-02,
-8.969659E-02,
-8.010870E-02,
-7.020049E-02,
-6.271743E-02,
-5.487298E-02,
-4.855121E-02,
-4.270647E-02,
-4.271049E-02,
-3.784891E-02,
-3.777571E-02
]

def regression_intercept_and_error(x, y):
    model = LinearRegression()
    model.fit(x, y)

    # Predicted values
    y_pred = model.predict(x)

    # Residuals
    residuals = y - y_pred

    # Degrees of freedom
    dof = len(y) - 2

    # Residual standard error
    residual_std_error = np.sqrt(np.sum(residuals**2) / dof)

    # Standard error of intercept
    x_mean = np.mean(x)
    x_diff_sq_sum = np.sum((x - x_mean) ** 2)
    intercept_std_error = residual_std_error * np.sqrt(np.sum(x ** 2) / (len(y) * x_diff_sq_sum))

    return model.intercept_, intercept_std_error

# Only using points from 3 to 6
points_to_fit = range(3, 7)

intercept_estimates = []
intercept_errors = []

for points in points_to_fit:
    x_fit = np.array(rpt2[-points:]).reshape(-1, 1)
    y_fit = np.array(Energy[-points:])
    
    intercept, intercept_error = regression_intercept_and_error(x_fit, y_fit)
    intercept_estimates.append(intercept)
    intercept_errors.append(intercept_error)
    
    # Print the intercept and its error
    print(f"Points used: {points}, Intercept: {intercept}, Error: {intercept_error}")

# Plotting intercept estimate with error bars
plt.figure(figsize=(8, 6))

plt.errorbar(points_to_fit, intercept_estimates, yerr=intercept_errors, fmt='o', color='blue', ecolor='red', capsize=5, label='exFCI')

plt.xlabel('Number of Points Used in Fit', fontsize=14)
plt.ylabel('exFCI', fontsize=14)
plt.title('exFCI errors as a Function of Number of Points 1.80Å', fontsize=16)
plt.grid(True)
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Points used: 3, Intercept: -10.30571989031021, Error: 0.0015759284913037489
# Points used: 4, Intercept: -10.305774180301576, Error: 0.0009310103706299656
# Points used: 5, Intercept: -10.301980493389708, Error: 0.001601076610569963
# Points used: 6, Intercept: -10.300416941096474, Error: 0.001089467760563813

# %%
##2.0
Energy = [
-9.26249559,
-9.27402197,
-9.29123429,
-9.31884151,
-9.3727868,
-9.43214675,
-9.49025675,
-9.53051089,
-9.54707136,
-9.5793969,
-9.61175699,
-9.66198191,
-9.71172585,
-9.75693532,
-9.78746776,
-9.82311135,
-9.85939065,
-9.89919931,
-9.93153972,
-9.95894304,
-9.98835619,
-10.01204421,
-10.03192974,
-10.04891131
]
rpt2 = [
-2.7439440E-01,
-2.7617850E-01,
-2.8115120E-01,
-2.8049150E-01,
-2.6279230E-01,
-2.4613170E-01,
-2.2046330E-01,
-2.0493090E-01,
-2.0261510E-01,
-1.9220520E-01,
-1.7991570E-01,
-1.6050340E-01,
-1.4420740E-01,
-1.2764900E-01,
-1.1770070E-01,
-1.0591420E-01,
-9.3997130E-02,
-8.0664640E-02,
-7.0062840E-02,
-6.1061290E-02,
-5.1121050E-02,
-4.3292120E-02,
-3.6535620E-02,
-3.0941970E-02
]

pt2=[
-0.571800,
-0.559158,
-0.536987,
-0.490073,
-0.392381,
-0.333573,
-0.275889,
-0.246833,
-0.241534,
-0.224045,
-0.205366,
-0.178362,
-0.157190,
-0.136813,
-0.124972,
-0.111358,
-0.097981,
-0.083375,
-0.071980,
-0.062440,
-0.052034,
-0.043970,
-0.036966,
-0.031242,
]
n_det= [
1,
9,
18,
42,
84,
171,
343,
689,
1429,
2901,
5803,
11608,
23278,
46763,
93532,
187072,
374927,
750183,
1500961,
3001945,
6004418,
12008951,
24018015,
48037118
]

last_points = 10
last_points1 = 4
last_points2 = 3
last_points3 = 23
determinants =np.array(n_det)
x_fit = np.array(rpt2[-last_points:]).reshape(-1, 1)
x_fit1 = np.array(rpt2[-last_points1:]).reshape(-1, 1)
x_fit2 = np.array(rpt2[-last_points2:]).reshape(-1, 1)
x_fit3 = np.array(rpt2[-last_points3:]).reshape(-1, 1)

y_fit = np.array(Energy[-last_points:])
y_fit1 = np.array(Energy[-last_points1:])
y_fit2 = np.array(Energy[-last_points2:])
y_fit3 = np.array(Energy[-last_points3:])

model = LinearRegression()
model.fit(x_fit, y_fit)
model1 = LinearRegression()
model1.fit(x_fit1, y_fit1)
model2 = LinearRegression()
model2.fit(x_fit2, y_fit2)

model3 = LinearRegression()
model3.fit(x_fit3, y_fit3)

# Calculate R^2
r_squared10 = model.score(x_fit, y_fit)
print(f'R^2;10: {r_squared10}')

r_squared4 = model1.score(x_fit1, y_fit1)
print(f'R^2;4: {r_squared4}')

r_squared3 = model2.score(x_fit2, y_fit2)
print(f'R^2;3: {r_squared3}')

r_squared6 = model3.score(x_fit3, y_fit3)
print(f'R^2;6: {r_squared6}')

# Y-value at x=0 (intercept)
y_intercept10 = model.intercept_
print(f'Y-value at x=0 10: {y_intercept10}')

y_intercept4 = model1.intercept_
print(f'Y-value at x=0 4: {y_intercept4}')

y_intercept3 = model2.intercept_
print(f'Y-value at x=0 3: {y_intercept3}')

y_intercept6 = model3.intercept_
print(f'Y-value at x=0 6: {y_intercept6}')

# Extend the fit line to min x value of -0.35
x_extended = np.linspace(-0.20, 0.0, 300).reshape(-1, 1)
y_extended = model.predict(x_extended)

x_extended1 = np.linspace(-0.20, 0.0, 300).reshape(-1, 1)
y_extended1 = model1.predict(x_extended1)

x_extended2 = np.linspace(-0.20, 0.0, 300).reshape(-1, 1)
y_extended2 = model2.predict(x_extended2)

x_extended3 = np.linspace(-0.20, 0.0, 300).reshape(-1, 1)
y_extended3 = model3.predict(x_extended3)

##non - linear plots
x_fit_quad1 = np.array(pt2[-last_points1:])
y_fit_quad1= np.array(Energy[-last_points1:])

x_fit_quad2 = np.array(pt2[-last_points2:])
y_fit_quad2= np.array(Energy[-last_points2:])

x_fit_quad3 = np.array(pt2[-last_points3:])
y_fit_quad3= np.array(Energy[-last_points3:])

def model_func(pt2, a, b, c):
    return a + (abs(c)/2) - b * pt2 - np.sqrt((c/2)**2 + (b * pt2)**2)

popt, _ = curve_fit(model_func, x_fit_quad1, y_fit_quad1)
a1, b1, c1 = popt

popt, _ = curve_fit(model_func, x_fit_quad2, y_fit_quad2)
a2, b2, c2 = popt

popt, _ = curve_fit(model_func, x_fit_quad3, y_fit_quad3)
a3, b3, c3 = popt


print(f'Fitted Non-linear Energies:\na4pts = {a1}\na3pts = {a2}\na6pts = {a3}')

x_extended_quad1 = np.linspace(-0.20, 0.0, 300)
y_extended_quad1 = model_func(x_extended_quad1, a1, b1, c1)

x_extended_quad2 = np.linspace(-0.20, 0.0, 300)
y_extended_quad2 = model_func(x_extended_quad2, a2, b2, c2)

x_extended_quad3 = np.linspace(-0.60, 0.0, 300)
y_extended_quad3 = model_func(x_extended_quad3, a3, b3, c3)

# Plotting Energy and exFCI against PT2
plt.figure(figsize=(18, 6))

plt.subplot(1,2,1)

# Plotting Energy against PT2 with the fitted line
#plt.plot(rpt2, Energy, linestyle='solid', marker='o', markerfacecolor ='none', markeredgecolor = 'black', color = 'black')

plt.plot(pt2, Energy, linestyle='solid', marker='o', markerfacecolor ='none', markeredgecolor = 'blue', color = 'black')

#plt.plot(x_extended, y_extended, label='10', linestyle='--', color='red')

#plt.plot(x_extended1, y_extended1, label='4-point extrapolation', linestyle='--', color='red')

#plt.plot(x_extended2, y_extended2, label='3-point extrapolation', linestyle='--', color='green')

#plt.plot(x_extended_quad1, y_extended_quad1, label='Non-Liear Fit-4pts', linestyle='--', color='magenta')

#plt.plot(x_extended_quad2, y_extended_quad2, label='Non-Liear Fit-3pts', linestyle='--', color='black')

plt.plot(x_extended_quad3, y_extended_quad3, label='α-1 points non-linear extrapolation', linestyle='--', color='red')

#plt.plot(x_extended3, y_extended3, label='6-point extrapolation', linestyle='--', color='blue')

#plt.axhline(y=[y_intercept3], color='black', linestyle='-', marker='o', markerfacecolor ='none', markeredgecolor = 'black', linewidth = 2.0)# label=f'{y_intercept3}')

#plt.xlim([-0.10, 0.00])
#plt.ylim([-8.40, -8.275])
plt.xlabel('$E^{pt2}$ ($E_h$)', fontsize=20)
plt.ylabel('Variational Energy $E_{0}$ ($E_h$)', fontsize=15)
plt.title('$H20$ 2.00Å', fontsize=16)
plt.legend()
plt.grid(color = 'gray', linestyle = ':', linewidth = 1.5)



plt.subplot(1,2,2)
plt.plot(rpt2, Energy, linestyle='solid', marker='o', markerfacecolor ='none', markeredgecolor = 'black', color = 'black')
plt.plot(x_extended2, y_extended2, label='3-point extrapolation', linestyle='--', color='green')

plt.xlabel('$E_{r}^{PT2}$ ($E_h$)', fontsize=20)
plt.ylabel('Variational Energy $E_{0}$ ($E_h$)', fontsize=15)
plt.title('$H20$ 2.00Å', fontsize=16)
plt.legend()
plt.grid(color = 'gray', linestyle = ':', linewidth = 1.5)
plt.tight_layout()
plt.show()
# Out:
# R^2;10: 0.9999899550710705
# R^2;4: 0.9999665093527638
# R^2;3: 0.9999214605349289
# R^2;6: 0.9975894757818
# Y-value at x=0 10: -10.142382172475934
# Y-value at x=0 4: -10.14152997188521
# Y-value at x=0 3: -10.141130224594777
# Y-value at x=0 6: -10.140970113742428
# Fitted Non-linear Energies:
# a4pts = -10.139624825637961
# a3pts = -10.153653989686417
# a6pts = -10.176588936712838
# /opt/anaconda3/lib/python3.11/site-packages/scipy/optimize/_minpack_py.py:1010: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',

# %%
##2.0
Energy = [
-9.26249559,
-9.27402197,
-9.29123429,
-9.31884151,
-9.3727868,
-9.43214675,
-9.49025675,
-9.53051089,
-9.54707136,
-9.5793969,
-9.61175699,
-9.66198191,
-9.71172585,
-9.75693532,
-9.78746776,
-9.82311135,
-9.85939065,
-9.89919931,
-9.93153972,
-9.95894304,
-9.98835619,
-9.98835619,
-10.01204421,
-10.01204421,
-10.03192974,
-10.04891131
]
rpt2 = [
-2.7439440E-01,
-2.7617850E-01,
-2.8115120E-01,
-2.8049150E-01,
-2.6279230E-01,
-2.4613170E-01,
-2.2046330E-01,
-2.0493090E-01,
-2.0261510E-01,
-1.9220520E-01,
-1.7991570E-01,
-1.6050340E-01,
-1.4420740E-01,
-1.2764900E-01,
-1.1770070E-01,
-1.0591420E-01,
-9.3997130E-02,
-8.0664640E-02,
-7.0062840E-02,
-6.1061290E-02,
-5.1121050E-02,
-5.1119870E-02,
-4.3341630E-02,
-4.3292120E-02,
-3.6535620E-02,
-3.0941970E-02
]

pt2=[
-0.571800,
-0.559158,
-0.536987,
-0.490073,
-0.392381,
-0.333573,
-0.275889,
-0.246833,
-0.241534,
-0.224045,
-0.205366,
-0.178362,
-0.157190,
-0.136813,
-0.124972,
-0.111358,
-0.097981,
-0.083375,
-0.071980,
-0.062440,
-0.052034,
-0.043970,
-0.036966,
-0.031242,

]

def regression_intercept_and_error(x, y):
    model = LinearRegression()
    model.fit(x, y)

    # Predicted values
    y_pred = model.predict(x)

    # Residuals
    residuals = y - y_pred

    # Degrees of freedom
    dof = len(y) - 2

    # Residual standard error
    residual_std_error = np.sqrt(np.sum(residuals**2) / dof)

    # Standard error of intercept
    x_mean = np.mean(x)
    x_diff_sq_sum = np.sum((x - x_mean) ** 2)
    intercept_std_error = residual_std_error * np.sqrt(np.sum(x ** 2) / (len(y) * x_diff_sq_sum))

    return model.intercept_, intercept_std_error

# Only using points from 3 to 6
points_to_fit = range(3, 7)

intercept_estimates = []
intercept_errors = []

for points in points_to_fit:
    x_fit = np.array(rpt2[-points:]).reshape(-1, 1)
    y_fit = np.array(Energy[-points:])
    
    intercept, intercept_error = regression_intercept_and_error(x_fit, y_fit)
    intercept_estimates.append(intercept)
    intercept_errors.append(intercept_error)

# Plotting intercept estimate with error bars
plt.figure(figsize=(8, 6))

plt.errorbar(points_to_fit, intercept_estimates, yerr=intercept_errors, fmt='o', color='blue', ecolor='red', capsize=5, label='exFCI')

plt.xlabel('Number of Points Used in Fit', fontsize=14)
plt.ylabel('exFCI', fontsize=14)
plt.title('exFCI errors as a Function of Number of Points $H_{20}$ 2.00Å', fontsize=16)
plt.grid(True)
plt.legend()

plt.tight_layout()
plt.show()

# %%
##1.60
Energy = [
-9.883636,
-9.8942653,
-9.91221831,
-9.93964175,
-9.97883546,
-10.02616669,
-10.05742095,
-10.09000554,
-10.11463225,
-10.1543808,
-10.19340307,
-10.21978884,
-10.24616569,
-10.26702428,
-10.28282509,
-10.29758472,
-10.31461625,
-10.3318372,
-10.34984579,
-10.36563741,
-10.37965782,
-10.39228723,
-10.40466333
]
rpt2 = [
-2.6073320E-01,
-2.6193590E-01,
-2.5920560E-01,
-2.5526550E-01,
-2.3455380E-01,
-2.0941130E-01,
-1.9284720E-01,
-1.7780540E-01,
-1.6839430E-01,
-1.5167990E-01,
-1.3288400E-01,
-1.1652680E-01,
-9.8951070E-02,
-8.7093680E-02,
-8.1339190E-02,
-7.7184800E-02,
-7.0940380E-02,
-6.4036160E-02,
-5.6770110E-02,
-5.0150680E-02,
-4.4415230E-02,
-3.9119470E-02,
-3.4128760E-02
]

pt2 = [
    -0.4224923,
-0.4110454,
-0.3894340,
-0.3613648,
-0.3052907,
-0.2535943,
-0.2265060,
-0.2035575,
-0.1897474,
-0.1671630,
-0.1431754,
-0.1238092,
-0.1039448,
-0.0908133,
-0.0844699,
-0.0798851,
-0.0731004,
-0.0657067,
-0.0580094,
-0.0510718,
-0.0451052,
-0.0396327,
-0.0345031,


]

n_det = [
    1,
9,
23,
50,
104,
212,
426,
858,
1731,
3463,
6930,
13862,
27781,
55564,
111178,
222358,
444750,
889649,
1779309,
3559471,
7118961,
14237941,
28476429,


]


last_points = 10
last_points1 = 4
last_points2 = 3
last_points3 = 23
determinants =np.array(n_det)
x_fit = np.array(rpt2[-last_points:]).reshape(-1, 1)
x_fit1 = np.array(rpt2[-last_points1:]).reshape(-1, 1)
x_fit2 = np.array(rpt2[-last_points2:]).reshape(-1, 1)
x_fit3 = np.array(rpt2[-last_points3:]).reshape(-1, 1)

y_fit = np.array(Energy[-last_points:])
y_fit1 = np.array(Energy[-last_points1:])
y_fit2 = np.array(Energy[-last_points2:])
y_fit3 = np.array(Energy[-last_points3:])

model = LinearRegression()
model.fit(x_fit, y_fit)
model1 = LinearRegression()
model1.fit(x_fit1, y_fit1)
model2 = LinearRegression()
model2.fit(x_fit2, y_fit2)

model3 = LinearRegression()
model3.fit(x_fit3, y_fit3)

# Calculate R^2
r_squared10 = model.score(x_fit, y_fit)
print(f'R^2;10: {r_squared10}')

r_squared4 = model1.score(x_fit1, y_fit1)
print(f'R^2;4: {r_squared4}')

r_squared3 = model2.score(x_fit2, y_fit2)
print(f'R^2;3: {r_squared3}')

r_squared6 = model3.score(x_fit3, y_fit3)
print(f'R^2;6: {r_squared6}')

# Y-value at x=0 (intercept)
y_intercept10 = model.intercept_
print(f'Y-value at x=0 10: {y_intercept10}')

y_intercept4 = model1.intercept_
print(f'Y-value at x=0 4: {y_intercept4}')

y_intercept3 = model2.intercept_
print(f'Y-value at x=0 3: {y_intercept3}')

y_intercept6 = model3.intercept_
print(f'Y-value at x=0 6: {y_intercept6}')

# Extend the fit line to min x value of -0.35
x_extended = np.linspace(-0.20, 0.0, 300).reshape(-1, 1)
y_extended = model.predict(x_extended)

x_extended1 = np.linspace(-0.20, 0.0, 300).reshape(-1, 1)
y_extended1 = model1.predict(x_extended1)

x_extended2 = np.linspace(-0.20, 0.0, 300).reshape(-1, 1)
y_extended2 = model2.predict(x_extended2)

x_extended3 = np.linspace(-0.20, 0.0, 300).reshape(-1, 1)
y_extended3 = model3.predict(x_extended3)

##non - linear plots
x_fit_quad1 = np.array(pt2[-last_points1:])
y_fit_quad1= np.array(Energy[-last_points1:])

x_fit_quad2 = np.array(pt2[-last_points2:])
y_fit_quad2= np.array(Energy[-last_points2:])

x_fit_quad3 = np.array(pt2[-last_points3:])
y_fit_quad3= np.array(Energy[-last_points3:])

def model_func(pt2, a, b, c):
    return a + (abs(c)/2) - b * pt2 - np.sqrt((c/2)**2 + (b * pt2)**2)

popt, _ = curve_fit(model_func, x_fit_quad1, y_fit_quad1)
a1, b1, c1 = popt

popt, _ = curve_fit(model_func, x_fit_quad2, y_fit_quad2)
a2, b2, c2 = popt

popt, _ = curve_fit(model_func, x_fit_quad3, y_fit_quad3)
a3, b3, c3 = popt


print(f'Fitted Non-linear Energies:\na4pts = {a1}\na3pts = {a2}\na6pts = {a3}')

x_extended_quad1 = np.linspace(-0.20, 0.0, 300)
y_extended_quad1 = model_func(x_extended_quad1, a1, b1, c1)

x_extended_quad2 = np.linspace(-0.20, 0.0, 300)
y_extended_quad2 = model_func(x_extended_quad2, a2, b2, c2)

x_extended_quad3 = np.linspace(-0.40, 0.0, 300)
y_extended_quad3 = model_func(x_extended_quad3, a3, b3, c3)

# Plotting Energy and exFCI against PT2
plt.figure(figsize=(18, 6))

plt.subplot(1,2,1)

# Plotting Energy against PT2 with the fitted line
#plt.plot(rpt2, Energy, linestyle='solid', marker='o', markerfacecolor ='none', markeredgecolor = 'black', color = 'black')

plt.plot(pt2, Energy, linestyle='solid', marker='o', markerfacecolor ='none', markeredgecolor = 'blue', color = 'black')

#plt.plot(x_extended, y_extended, label='10', linestyle='--', color='red')

#plt.plot(x_extended1, y_extended1, label='4-point extrapolation', linestyle='--', color='red')

#plt.plot(x_extended2, y_extended2, label='3-point extrapolation', linestyle='--', color='green')

#plt.plot(x_extended_quad1, y_extended_quad1, label='Non-Liear Fit-4pts', linestyle='--', color='magenta')

#plt.plot(x_extended_quad2, y_extended_quad2, label='Non-Liear Fit-3pts', linestyle='--', color='black')

plt.plot(x_extended_quad3, y_extended_quad3, label='α-1 points non-linear extrapolation', linestyle='--', color='red')

#plt.plot(x_extended3, y_extended3, label='6-point extrapolation', linestyle='--', color='blue')

#plt.axhline(y=[y_intercept3], color='black', linestyle='-', marker='o', markerfacecolor ='none', markeredgecolor = 'black', linewidth = 2.0)# label=f'{y_intercept3}')

#plt.xlim([-0.10, 0.00])
#plt.ylim([-8.40, -8.275])
plt.xlabel('$E^{pt2}$ ($E_h$)', fontsize=20)
plt.ylabel('Variational Energy $E_{0}$ ($E_h$)', fontsize=15)
plt.title('$H20$ 1.60Å', fontsize=16)
plt.legend()
plt.grid(color = 'gray', linestyle = ':', linewidth = 1.5)



plt.subplot(1,2,2)
plt.plot(rpt2, Energy, linestyle='solid', marker='o', markerfacecolor ='none', markeredgecolor = 'black', color = 'black')
plt.plot(x_extended2, y_extended2, label='3-point extrapolation', linestyle='--', color='green')

plt.xlabel('$E_{r}^{PT2}$ ($E_h$)', fontsize=20)
plt.ylabel('Variational Energy $E_{0}$ ($E_h$)', fontsize=15)
plt.title('$H20$ 1.60Å', fontsize=16)
plt.legend()
plt.grid(color = 'gray', linestyle = ':', linewidth = 1.5)
plt.tight_layout()
plt.show()
# Out:
# R^2;10: 0.9980386151274194
# R^2;4: 0.9999528243914035
# R^2;3: 0.9998729625690135
# R^2;6: 0.9964997775886547
# Y-value at x=0 10: -10.494074222014662
# Y-value at x=0 4: -10.487531455895775
# Y-value at x=0 3: -10.487527594093864
# Y-value at x=0 6: -10.47049184433315
# Fitted Non-linear Energies:
# a4pts = -10.490152877895472
# a3pts = -10.502287037843534
# a6pts = -10.489365843272438
# /opt/anaconda3/lib/python3.11/site-packages/scipy/optimize/_minpack_py.py:1010: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',

# %%
#1.60
Energy = [
-9.883636,
-9.8942653,
-9.91221831,
-9.93964175,
-9.97883546,
-10.02616669,
-10.05742095,
-10.09000554,
-10.11463225,
-10.1543808,
-10.19340307,
-10.21978884,
-10.24616569,
-10.26702428,
-10.28282509,
-10.29758472,
-10.31461625,
-10.3318372,
-10.34984579,
-10.36563741,
-10.37965782,
-10.39228723,
-10.40466333
]
rpt2 = [
-2.6073320E-01,
-2.6193590E-01,
-2.5920560E-01,
-2.5526550E-01,
-2.3455380E-01,
-2.0941130E-01,
-1.9284720E-01,
-1.7780540E-01,
-1.6839430E-01,
-1.5167990E-01,
-1.3288400E-01,
-1.1652680E-01,
-9.8951070E-02,
-8.7093680E-02,
-8.1339190E-02,
-7.7184800E-02,
-7.0940380E-02,
-6.4036160E-02,
-5.6770110E-02,
-5.0150680E-02,
-4.4415230E-02,
-3.9119470E-02,
-3.4128760E-02
]

def regression_intercept_and_error(x, y):
    model = LinearRegression()
    model.fit(x, y)

    # Predicted values
    y_pred = model.predict(x)

    # Residuals
    residuals = y - y_pred

    # Degrees of freedom
    dof = len(y) - 2

    # Residual standard error
    residual_std_error = np.sqrt(np.sum(residuals**2) / dof)

    # Standard error of intercept
    x_mean = np.mean(x)
    x_diff_sq_sum = np.sum((x - x_mean) ** 2)
    intercept_std_error = residual_std_error * np.sqrt(np.sum(x ** 2) / (len(y) * x_diff_sq_sum))

    return model.intercept_, intercept_std_error

# Only using points from 3 to 6
points_to_fit = range(3, 7)

intercept_estimates = []
intercept_errors = []

for points in points_to_fit:
    x_fit = np.array(rpt2[-points:]).reshape(-1, 1)
    y_fit = np.array(Energy[-points:])
    
    intercept, intercept_error = regression_intercept_and_error(x_fit, y_fit)
    intercept_estimates.append(intercept)
    intercept_errors.append(intercept_error)
    
    # Print the intercept and its error
    print(f"Points used: {points}, Intercept: {intercept}, Error: {intercept_error}")

# Plotting intercept estimate with error bars
plt.figure(figsize=(8, 6))

plt.errorbar(points_to_fit, intercept_estimates, yerr=intercept_errors, fmt='o', color='blue', ecolor='red', capsize=5, label='exFCI')

plt.xlabel('Number of Points Used in Fit', fontsize=14)
plt.ylabel('exFCI', fontsize=14)
plt.title('exFCI errors as a Function of Number of Points 1.60Å', fontsize=16)
plt.grid(True)
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Points used: 3, Intercept: -10.487527594093864, Error: 0.0010806257388745293
# Points used: 4, Intercept: -10.487531455895775, Error: 0.0005002396018492213
# Points used: 5, Intercept: -10.487094239767226, Error: 0.0003942168256089769
# Points used: 6, Intercept: -10.487436973522685, Error: 0.00033472695137722844

# %%
##1.40
Energy = [
-10.211488490,
-10.223282730,
-10.241731220,
-10.262028350,
-10.290284230,
-10.322977080,
-10.351125870,
-10.379534020,
-10.416477840,
-10.452626290,
-10.483436740,
-10.512395280,
-10.533995120,
-10.552550620,
-10.563837660,
-10.575058050,
-10.587312270,
-10.599977200,
-10.612231870,
-10.624005980,
-10.634842730,
-10.644479400,
-10.652828510
]
rpt2 = [
-2.540703E-01,
-2.537797E-01,
-2.479393E-01,
-2.434109E-01,
-2.283694E-01,
-2.074752E-01,
-1.924169E-01,
-1.767663E-01,
-1.552240E-01,
-1.353536E-01,
-1.166979E-01,
-9.610532E-02,
-8.010348E-02,
-6.827138E-02,
-6.397364E-02,
-6.076634E-02,
-5.661752E-02,
-5.118298E-02,
-4.535084E-02,
-3.966712E-02,
-3.430490E-02,
-2.939425E-02,
-2.519441E-02
]

pt2 = [
    -0.3741246,
-0.3607962,
-0.3386572,
-0.3189484,
-0.2832315,
-0.2463761,
-0.2222418,
-0.1993852,
-0.1706831,
-0.1456009,
-0.1235755,
-0.1004417,
-0.0829806,
-0.0702848,
-0.0656712,
-0.0622307,
-0.0578274,
-0.0521252,
-0.0460539,
-0.0401781,
-0.0346688,
-0.0296497,
-0.0253743,


]

n_det = [
    1,
9,
23,
46,
98,
196,
396,
794,
1611,
3255,
6513,
13027,
26059,
52126,
104254,
208543,
417152,
834322,
1668660,
3337366,
6674745,
13349510,
26699041,

]


last_points = 10
last_points1 = 4
last_points2 = 3
last_points3 = 22
determinants =np.array(n_det)
x_fit = np.array(rpt2[-last_points:]).reshape(-1, 1)
x_fit1 = np.array(rpt2[-last_points1:]).reshape(-1, 1)
x_fit2 = np.array(rpt2[-last_points2:]).reshape(-1, 1)
x_fit3 = np.array(rpt2[-last_points3:]).reshape(-1, 1)

y_fit = np.array(Energy[-last_points:])
y_fit1 = np.array(Energy[-last_points1:])
y_fit2 = np.array(Energy[-last_points2:])
y_fit3 = np.array(Energy[-last_points3:])

model = LinearRegression()
model.fit(x_fit, y_fit)
model1 = LinearRegression()
model1.fit(x_fit1, y_fit1)
model2 = LinearRegression()
model2.fit(x_fit2, y_fit2)

model3 = LinearRegression()
model3.fit(x_fit3, y_fit3)

# Calculate R^2
r_squared10 = model.score(x_fit, y_fit)
print(f'R^2;10: {r_squared10}')

r_squared4 = model1.score(x_fit1, y_fit1)
print(f'R^2;4: {r_squared4}')

r_squared3 = model2.score(x_fit2, y_fit2)
print(f'R^2;3: {r_squared3}')

r_squared6 = model3.score(x_fit3, y_fit3)
print(f'R^2;6: {r_squared6}')

# Y-value at x=0 (intercept)
y_intercept10 = model.intercept_
print(f'Y-value at x=0 10: {y_intercept10}')

y_intercept4 = model1.intercept_
print(f'Y-value at x=0 4: {y_intercept4}')

y_intercept3 = model2.intercept_
print(f'Y-value at x=0 3: {y_intercept3}')

y_intercept6 = model3.intercept_
print(f'Y-value at x=0 6: {y_intercept6}')

# Extend the fit line to min x value of -0.35
x_extended = np.linspace(-0.20, 0.0, 300).reshape(-1, 1)
y_extended = model.predict(x_extended)

x_extended1 = np.linspace(-0.20, 0.0, 300).reshape(-1, 1)
y_extended1 = model1.predict(x_extended1)

x_extended2 = np.linspace(-0.20, 0.0, 300).reshape(-1, 1)
y_extended2 = model2.predict(x_extended2)

x_extended3 = np.linspace(-0.20, 0.0, 300).reshape(-1, 1)
y_extended3 = model3.predict(x_extended3)

##non - linear plots
x_fit_quad1 = np.array(pt2[-last_points1:])
y_fit_quad1= np.array(Energy[-last_points1:])

x_fit_quad2 = np.array(pt2[-last_points2:])
y_fit_quad2= np.array(Energy[-last_points2:])

x_fit_quad3 = np.array(pt2[-last_points3:])
y_fit_quad3= np.array(Energy[-last_points3:])

def model_func(pt2, a, b, c):
    return a + (abs(c)/2) - b * pt2 - np.sqrt((c/2)**2 + (b * pt2)**2)

popt, _ = curve_fit(model_func, x_fit_quad1, y_fit_quad1)
a1, b1, c1 = popt

popt, _ = curve_fit(model_func, x_fit_quad2, y_fit_quad2)
a2, b2, c2 = popt

popt, _ = curve_fit(model_func, x_fit_quad3, y_fit_quad3)
a3, b3, c3 = popt


print(f'Fitted Non-linear Energies:\na4pts = {a1}\na3pts = {a2}\na6pts = {a3}')

x_extended_quad1 = np.linspace(-0.20, 0.0, 300)
y_extended_quad1 = model_func(x_extended_quad1, a1, b1, c1)

x_extended_quad2 = np.linspace(-0.20, 0.0, 300)
y_extended_quad2 = model_func(x_extended_quad2, a2, b2, c2)

x_extended_quad3 = np.linspace(-0.35, 0.0, 300)
y_extended_quad3 = model_func(x_extended_quad3, a3, b3, c3)

# Plotting Energy and exFCI against PT2
plt.figure(figsize=(18, 6))

plt.subplot(1,2,1)

# Plotting Energy against PT2 with the fitted line
#plt.plot(rpt2, Energy, linestyle='solid', marker='o', markerfacecolor ='none', markeredgecolor = 'black', color = 'black')

plt.plot(pt2, Energy, linestyle='solid', marker='o', markerfacecolor ='none', markeredgecolor = 'blue', color = 'black')

#plt.plot(x_extended, y_extended, label='10', linestyle='--', color='red')

#plt.plot(x_extended1, y_extended1, label='4-point extrapolation', linestyle='--', color='red')

#plt.plot(x_extended2, y_extended2, label='3-point extrapolation', linestyle='--', color='green')

#plt.plot(x_extended_quad1, y_extended_quad1, label='Non-Liear Fit-4pts', linestyle='--', color='magenta')

#plt.plot(x_extended_quad2, y_extended_quad2, label='Non-Liear Fit-3pts', linestyle='--', color='black')

plt.plot(x_extended_quad3, y_extended_quad3, label='α-1 points non-linear extrapolation', linestyle='--', color='red')

#plt.plot(x_extended3, y_extended3, label='6-point extrapolation', linestyle='--', color='blue')

#plt.axhline(y=[y_intercept3], color='black', linestyle='-', marker='o', markerfacecolor ='none', markeredgecolor = 'black', linewidth = 2.0)# label=f'{y_intercept3}')

#plt.xlim([-0.10, 0.00])
#plt.ylim([-8.40, -8.275])
plt.xlabel('$E^{pt2}$ ($E_h$)', fontsize=20)
plt.ylabel('Variational Energy $E_{0}$ ($E_h$)', fontsize=15)
plt.title('$H20$ 1.40Å', fontsize=16)
plt.legend()
plt.grid(color = 'gray', linestyle = ':', linewidth = 1.5)



plt.subplot(1,2,2)
plt.plot(rpt2, Energy, linestyle='solid', marker='o', markerfacecolor ='none', markeredgecolor = 'black', color = 'black')
plt.plot(x_extended2, y_extended2, label='3-point extrapolation', linestyle='--', color='green')

plt.xlabel('$E_{r}^{PT2}$ ($E_h$)', fontsize=20)
plt.ylabel('Variational Energy $E_{0}$ ($E_h$)', fontsize=15)
plt.title('$H20$ 1.40Å', fontsize=16)
plt.legend()
plt.grid(color = 'gray', linestyle = ':', linewidth = 1.5)
plt.tight_layout()
plt.show()
# Out:
# R^2;10: 0.9928427378163232
# R^2;4: 0.9999635192736189
# R^2;3: 0.9999862552687259
# R^2;6: 0.9971502426515185
# Y-value at x=0 10: -10.713672062993794
# Y-value at x=0 4: -10.702964060084167
# Y-value at x=0 3: -10.702537848709266
# Y-value at x=0 6: -10.689501007812204
# Fitted Non-linear Energies:
# a4pts = -10.702179426559791
# a3pts = -10.705060112954408
# a6pts = -10.701244358734547
# /opt/anaconda3/lib/python3.11/site-packages/scipy/optimize/_minpack_py.py:1010: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',

# %%
##1.40
Energy = [
-10.211488490,
-10.223282730,
-10.241731220,
-10.262028350,
-10.290284230,
-10.322977080,
-10.351125870,
-10.379534020,
-10.416477840,
-10.452626290,
-10.483436740,
-10.512395280,
-10.533995120,
-10.552550620,
-10.563837660,
-10.575058050,
-10.587312270,
-10.599977200,
-10.612231870,
-10.624005980,
-10.634842730,
-10.644479400,
-10.652828510
]
rpt2 = [
-2.540703E-01,
-2.537797E-01,
-2.479393E-01,
-2.434109E-01,
-2.283694E-01,
-2.074752E-01,
-1.924169E-01,
-1.767663E-01,
-1.552240E-01,
-1.353536E-01,
-1.166979E-01,
-9.610532E-02,
-8.010348E-02,
-6.827138E-02,
-6.397364E-02,
-6.076634E-02,
-5.661752E-02,
-5.118298E-02,
-4.535084E-02,
-3.966712E-02,
-3.430490E-02,
-2.939425E-02,
-2.519441E-02
]

def regression_intercept_and_error(x, y):
    model = LinearRegression()
    model.fit(x, y)

    # Predicted values
    y_pred = model.predict(x)

    # Residuals
    residuals = y - y_pred

    # Degrees of freedom
    dof = len(y) - 2

    # Residual standard error
    residual_std_error = np.sqrt(np.sum(residuals**2) / dof)

    # Standard error of intercept
    x_mean = np.mean(x)
    x_diff_sq_sum = np.sum((x - x_mean) ** 2)
    intercept_std_error = residual_std_error * np.sqrt(np.sum(x ** 2) / (len(y) * x_diff_sq_sum))

    return model.intercept_, intercept_std_error

# Only using points from 3 to 6
points_to_fit = range(3, 7)

intercept_estimates = []
intercept_errors = []

for points in points_to_fit:
    x_fit = np.array(rpt2[-points:]).reshape(-1, 1)
    y_fit = np.array(Energy[-points:])
    
    intercept, intercept_error = regression_intercept_and_error(x_fit, y_fit)
    intercept_estimates.append(intercept)
    intercept_errors.append(intercept_error)
    
    # Print the intercept and its error
    print(f"Points used: {points}, Intercept: {intercept}, Error: {intercept_error}")

# Plotting intercept estimate with error bars
plt.figure(figsize=(8, 6))

plt.errorbar(points_to_fit, intercept_estimates, yerr=intercept_errors, fmt='o', color='blue', ecolor='red', capsize=5, label='exFCI')

plt.xlabel('Number of Points Used in Fit', fontsize=14)
plt.ylabel('exFCI', fontsize=14)
plt.title('exFCI errors as a Function of Number of Points 1.40Å', fontsize=16)
plt.grid(True)
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Points used: 3, Intercept: -10.702537848709266, Error: 0.00021854285654312853
# Points used: 4, Intercept: -10.702964060084167, Error: 0.00027686266229609086
# Points used: 5, Intercept: -10.703619416447177, Error: 0.00044365627510776064
# Points used: 6, Intercept: -10.704268287302249, Error: 0.0005215220552714182

# %%
##2.2
Energy = [
-8.99112903,
-9.00328449,
-9.0255385,
-9.06749294,
-9.1389182,
-9.21984622,
-9.28123279,
-9.3051788,
-9.33223367,
-9.37166455,
-9.43132193,
-9.49281661,
-9.54979436,
-9.58849224,
-9.638440350,
-9.688478640,
-9.741796190,
-9.784697590,
-9.831971650,
-9.875934400,
-9.911926260,
-9.940605140,
-9.963277080,
 -9.98281439,
]
rpt2 = [
-0.2773193,
-0.2802221,
-0.2865977,
-0.2894427,
-0.2749429,
-0.2496930,
-0.2239899,
-0.2217826,
-0.2154808,
-0.2034943,
-0.1828510,
-0.1626301,
-0.1456890,
-0.1347637,
-1.2181866E-01,
-1.0876704E-01,
-9.4062130E-02,
-8.3042520E-02,
-7.0131010E-02,
-5.7900350E-02,
-4.7458120E-02,
-3.8838450E-02,
-3.1603200E-02,
-0.02502576
]

last_points = 10
last_points1 = 4
last_points2 = 3
last_points3 = 6
x_fit = np.array(rpt2[-last_points:]).reshape(-1, 1)
x_fit1 = np.array(rpt2[-last_points1:]).reshape(-1, 1)
x_fit2 = np.array(rpt2[-last_points2:]).reshape(-1, 1)
x_fit3 = np.array(rpt2[-last_points3:]).reshape(-1, 1)

y_fit = np.array(Energy[-last_points:])
y_fit1 = np.array(Energy[-last_points1:])
y_fit2 = np.array(Energy[-last_points2:])
y_fit3 = np.array(Energy[-last_points3:])

model = LinearRegression()
model.fit(x_fit, y_fit)
model1 = LinearRegression()
model1.fit(x_fit1, y_fit1)
model2 = LinearRegression()
model2.fit(x_fit2, y_fit2)

model3 = LinearRegression()
model3.fit(x_fit3, y_fit3)

# Calculate R^2
r_squared10 = model.score(x_fit, y_fit)
print(f'R^2;10: {r_squared10}')

r_squared4 = model1.score(x_fit1, y_fit1)
print(f'R^2;4: {r_squared4}')

r_squared3 = model2.score(x_fit2, y_fit2)
print(f'R^2;3: {r_squared3}')

r_squared6 = model3.score(x_fit3, y_fit3)
print(f'R^2;6: {r_squared6}')

# Y-value at x=0 (intercept)
y_intercept10 = model.intercept_
print(f'Y-value at x=0 10: {y_intercept10}')

y_intercept4 = model1.intercept_
print(f'Y-value at x=0 4: {y_intercept4}')

y_intercept3 = model2.intercept_
print(f'Y-value at x=0 3: {y_intercept3}')

y_intercept6 = model3.intercept_
print(f'Y-value at x=0 6: {y_intercept6}')

# Extend the fit line to min x value of -0.35
x_extended = np.linspace(-0.20, 0.0, 300).reshape(-1, 1)
y_extended = model.predict(x_extended)

x_extended1 = np.linspace(-0.20, 0.0, 300).reshape(-1, 1)
y_extended1 = model1.predict(x_extended1)

x_extended2 = np.linspace(-0.20, 0.0, 300).reshape(-1, 1)
y_extended2 = model2.predict(x_extended2)

x_extended3 = np.linspace(-0.20, 0.0, 300).reshape(-1, 1)
y_extended3 = model3.predict(x_extended3)

##non - linear plots
x_fit_quad1 = np.array(rpt2[-last_points1:])
y_fit_quad1= np.array(Energy[-last_points1:])

x_fit_quad2 = np.array(rpt2[-last_points2:])
y_fit_quad2= np.array(Energy[-last_points2:])

x_fit_quad3 = np.array(rpt2[-last_points3:])
y_fit_quad3= np.array(Energy[-last_points3:])

def model_func(rpt2, a, b, c):
    return a + (abs(c)/2) - b * rpt2 - np.sqrt((c/2)**2 + (b * rpt2)**2)

popt, _ = curve_fit(model_func, x_fit_quad1, y_fit_quad1)
a1, b1, c1 = popt

popt, _ = curve_fit(model_func, x_fit_quad2, y_fit_quad2)
a2, b2, c2 = popt

popt, _ = curve_fit(model_func, x_fit_quad3, y_fit_quad3)
a3, b3, c3 = popt


print(f'Fitted Non-linear Energies:\na4pts = {a1}\na3pts = {a2}\na6pts = {a3}')

x_extended_quad1 = np.linspace(-0.20, 0.0, 300)
y_extended_quad1 = model_func(x_extended_quad1, a1, b1, c1)

x_extended_quad2 = np.linspace(-0.20, 0.0, 300)
y_extended_quad2 = model_func(x_extended_quad2, a2, b2, c2)

x_extended_quad3 = np.linspace(-0.20, 0.0, 300)
y_extended_quad3 = model_func(x_extended_quad3, a3, b3, c3)

# Plotting Energy and exFCI against PT2
plt.figure(figsize=(6, 6))

# Plotting Energy against PT2 with the fitted line
plt.plot(rpt2, Energy, linestyle='solid', marker='o', markerfacecolor ='none', markeredgecolor = 'black', color = 'black')

#plt.plot(x_extended, y_extended, label='10', linestyle='--', color='red')

plt.plot(x_extended1, y_extended1, label='4-point extrapolation', linestyle='--', color='red')

plt.plot(x_extended2, y_extended2, label='3-point extrapolation', linestyle='--', color='green')

plt.plot(x_extended_quad1, y_extended_quad1, label='Non-Liear Fit-4pts', linestyle='--', color='magenta')

plt.plot(x_extended_quad2, y_extended_quad2, label='Non-Liear Fit-3pts', linestyle='--', color='black')

plt.plot(x_extended_quad3, y_extended_quad3, label='Non-Liear Fit-6pts', linestyle='--', color='orange')

plt.plot(x_extended3, y_extended3, label='6-point extrapolation', linestyle='--', color='blue')

plt.axhline(y=[y_intercept3], color='black', linestyle='-', marker='o', markerfacecolor ='none', markeredgecolor = 'black', linewidth = 2.0)# label=f'{y_intercept3}')

plt.xlim([-0.20, 0.00])
plt.ylim([-10.10, -9.4])
plt.xlabel('$E_{r}^{PT2}$ ($E_h$)', fontsize=20)
plt.ylabel('Variational Energy $E_{0}$ ($E_{h}$)', fontsize=20)
plt.title('H20 1.40Å', fontsize=20)
plt.legend()
plt.grid(color = 'gray', linestyle = ':', linewidth = 1.5)

plt.tight_layout()
plt.show()
# Out:
# R^2;10: 0.9990429384683
# R^2;4: 0.9993466791760831
# R^2;3: 0.999764041211678
# R^2;6: 0.9989168998398442
# Y-value at x=0 10: -10.07885747306186
# Y-value at x=0 4: -10.062656700620007
# Y-value at x=0 3: -10.059517396117819
# Y-value at x=0 6: -10.069097829544003
# Fitted Non-linear Energies:
# a4pts = -10.062658443484684
# a3pts = -10.059518235635627
# a6pts = -10.069100694546188
# /opt/anaconda3/lib/python3.11/site-packages/scipy/optimize/_minpack_py.py:1010: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',

# %%
##1.20
Energy = [
-10.50652529,
-10.51963493,
-10.53710418,
-10.55563464,
-10.57726747,
-10.60288215,
-10.62627578,
-10.65328676,
-10.68408108,
-10.71419545,
-10.74473498,
-10.77291739,
-10.8015608,
-10.81720736,
-10.82496614,
-10.83256069,
-10.84187325,
-10.85114001,
-10.85985281,
-10.86810672,
-10.87553807,
-10.88209277,
-10.88785682,
]
rpt2 = [
-0.2494675,
-0.2468528,
-0.2382079,
-0.2324125,
-0.2178973,
-0.2001991,
-0.1856325,
-0.1679215,
-0.1474644,
-0.1274443,
-0.1062905,
-0.0856506,
-0.0619059,
-0.0510889,
-0.0479706,
-0.0458604,
-0.0428306,
-0.0385434,
-0.0341164,
-0.0295181,
-0.0251944,
-0.0213082,
-0.0177028,
]

pt2 = [
-0.3385139,
-0.3229442,
-0.3009727,
-0.2842837,
-0.2581660,
-0.2296015,
-0.2086586,
-0.1847199,
-0.1590320,
-0.1351622,
-0.1112342,
-0.0886404,
-0.0633785,
-0.0520385,
-0.0487684,
-0.0465611,
-0.0434184,
-0.0389988,
-0.0344568,
-0.0297612,
-0.0253634,
-0.0214236,
-0.0177789,

]


n_det = [
1,
9,
22,
44,
90,
185,
373,
752,
1505,
3013,
6028,
12059,
24122,
48307,
96670,
193351,
386716,
773481,
1546968,
3093938,
6187895,
12375809,
24751623,

]


last_points = 10
last_points1 = 4
last_points2 = 3
last_points3 = 23
determinants =np.array(n_det)
x_fit = np.array(rpt2[-last_points:]).reshape(-1, 1)
x_fit1 = np.array(rpt2[-last_points1:]).reshape(-1, 1)
x_fit2 = np.array(rpt2[-last_points2:]).reshape(-1, 1)
x_fit3 = np.array(rpt2[-last_points3:]).reshape(-1, 1)

y_fit = np.array(Energy[-last_points:])
y_fit1 = np.array(Energy[-last_points1:])
y_fit2 = np.array(Energy[-last_points2:])
y_fit3 = np.array(Energy[-last_points3:])

model = LinearRegression()
model.fit(x_fit, y_fit)
model1 = LinearRegression()
model1.fit(x_fit1, y_fit1)
model2 = LinearRegression()
model2.fit(x_fit2, y_fit2)

model3 = LinearRegression()
model3.fit(x_fit3, y_fit3)

# Calculate R^2
r_squared10 = model.score(x_fit, y_fit)
print(f'R^2;10: {r_squared10}')

r_squared4 = model1.score(x_fit1, y_fit1)
print(f'R^2;4: {r_squared4}')

r_squared3 = model2.score(x_fit2, y_fit2)
print(f'R^2;3: {r_squared3}')

r_squared6 = model3.score(x_fit3, y_fit3)
print(f'R^2;6: {r_squared6}')

# Y-value at x=0 (intercept)
y_intercept10 = model.intercept_
print(f'Y-value at x=0 10: {y_intercept10}')

y_intercept4 = model1.intercept_
print(f'Y-value at x=0 4: {y_intercept4}')

y_intercept3 = model2.intercept_
print(f'Y-value at x=0 3: {y_intercept3}')

y_intercept6 = model3.intercept_
print(f'Y-value at x=0 6: {y_intercept6}')

# Extend the fit line to min x value of -0.35
x_extended = np.linspace(-0.20, 0.0, 300).reshape(-1, 1)
y_extended = model.predict(x_extended)

x_extended1 = np.linspace(-0.20, 0.0, 300).reshape(-1, 1)
y_extended1 = model1.predict(x_extended1)

x_extended2 = np.linspace(-0.20, 0.0, 300).reshape(-1, 1)
y_extended2 = model2.predict(x_extended2)

x_extended3 = np.linspace(-0.20, 0.0, 300).reshape(-1, 1)
y_extended3 = model3.predict(x_extended3)

##non - linear plots
x_fit_quad1 = np.array(pt2[-last_points1:])
y_fit_quad1= np.array(Energy[-last_points1:])

x_fit_quad2 = np.array(pt2[-last_points2:])
y_fit_quad2= np.array(Energy[-last_points2:])

x_fit_quad3 = np.array(pt2[-last_points3:])
y_fit_quad3= np.array(Energy[-last_points3:])

def model_func(pt2, a, b, c):
    return a + (abs(c)/2) - b * pt2 - np.sqrt((c/2)**2 + (b * pt2)**2)

popt, _ = curve_fit(model_func, x_fit_quad1, y_fit_quad1)
a1, b1, c1 = popt

popt, _ = curve_fit(model_func, x_fit_quad2, y_fit_quad2)
a2, b2, c2 = popt

popt, _ = curve_fit(model_func, x_fit_quad3, y_fit_quad3)
a3, b3, c3 = popt


print(f'Fitted Non-linear Energies:\na4pts = {a1}\na3pts = {a2}\na6pts = {a3}')

x_extended_quad1 = np.linspace(-0.20, 0.0, 300)
y_extended_quad1 = model_func(x_extended_quad1, a1, b1, c1)

x_extended_quad2 = np.linspace(-0.20, 0.0, 300)
y_extended_quad2 = model_func(x_extended_quad2, a2, b2, c2)

x_extended_quad3 = np.linspace(-0.30, 0.0, 300)
y_extended_quad3 = model_func(x_extended_quad3, a3, b3, c3)

# Plotting Energy and exFCI against PT2
plt.figure(figsize=(18, 6))

plt.subplot(1,2,1)

# Plotting Energy against PT2 with the fitted line
#plt.plot(rpt2, Energy, linestyle='solid', marker='o', markerfacecolor ='none', markeredgecolor = 'black', color = 'black')

plt.plot(pt2, Energy, linestyle='solid', marker='o', markerfacecolor ='none', markeredgecolor = 'blue', color = 'black')

#plt.plot(x_extended, y_extended, label='10', linestyle='--', color='red')

#plt.plot(x_extended1, y_extended1, label='4-point extrapolation', linestyle='--', color='red')

#plt.plot(x_extended2, y_extended2, label='3-point extrapolation', linestyle='--', color='green')

#plt.plot(x_extended_quad1, y_extended_quad1, label='Non-Liear Fit-4pts', linestyle='--', color='magenta')

#plt.plot(x_extended_quad2, y_extended_quad2, label='Non-Liear Fit-3pts', linestyle='--', color='black')

plt.plot(x_extended_quad3, y_extended_quad3, label='α-1 points non-linear extrapolation', linestyle='--', color='red')

#plt.plot(x_extended3, y_extended3, label='6-point extrapolation', linestyle='--', color='blue')

#plt.axhline(y=[y_intercept3], color='black', linestyle='-', marker='o', markerfacecolor ='none', markeredgecolor = 'black', linewidth = 2.0)# label=f'{y_intercept3}')

#plt.xlim([-0.10, 0.00])
#plt.ylim([-8.40, -8.275])
plt.xlabel('$E^{pt2}$ ($E_h$)', fontsize=20)
plt.ylabel('Variational Energy $E_{0}$ ($E_h$)', fontsize=15)
plt.title('$H20$ 1.20Å', fontsize=16)
plt.legend()
plt.grid(color = 'gray', linestyle = ':', linewidth = 1.5)



plt.subplot(1,2,2)
plt.plot(rpt2, Energy, linestyle='solid', marker='o', markerfacecolor ='none', markeredgecolor = 'black', color = 'black')
plt.plot(x_extended2, y_extended2, label='3-point extrapolation', linestyle='--', color='green')

plt.xlabel('$E_{r}^{PT2}$ ($E_h$)', fontsize=20)
plt.ylabel('Variational Energy $E_{0}$ ($E_h$)', fontsize=15)
plt.title('$H20$ 1.20Å', fontsize=16)
plt.legend()
plt.grid(color = 'gray', linestyle = ':', linewidth = 1.5)
plt.tight_layout()
plt.show()
# Out:
# R^2;10: 0.9864110239615879
# R^2;4: 0.9997438128538457
# R^2;3: 0.9997627950495644
# R^2;6: 0.9973153174864073
# Y-value at x=0 10: -10.92808943171048
# Y-value at x=0 4: -10.91762474038131
# Y-value at x=0 3: -10.917032825837717
# Y-value at x=0 6: -10.90928390569378
# Fitted Non-linear Energies:
# a4pts = -10.917328312092955
# a3pts = -10.916797924494645
# a6pts = -10.914183597895988
# /opt/anaconda3/lib/python3.11/site-packages/scipy/optimize/_minpack_py.py:1010: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',

# %%
##1.20
Energy = [
-10.50652529,
-10.51963493,
-10.53710418,
-10.55563464,
-10.57726747,
-10.60288215,
-10.62627578,
-10.65328676,
-10.68408108,
-10.71419545,
-10.74473498,
-10.77291739,
-10.8015608,
-10.81720736,
-10.824966140,
-10.832560690,
-10.841873250,
-10.851140010,
-10.859852810,
-10.868106720,
-10.875538070,
-10.882092770,
-10.887856820,
-10.89304574,
-10.89751688
]
rpt2 = [
-0.24946750,
-0.24685280,
-0.23820790,
-0.23241250,
-0.21789730,
-0.20019910,
-0.18563250,
-0.16792150,
-0.14746440,
-0.12744430,
-0.10629050,
-0.08565055,
-0.06190588,
-0.05108892,
-0.04797057,
-0.04586035,
-0.04283055,
-0.03854339,
-0.03411643,
-0.02951806,
-0.02519442,
-0.02130823,
-0.01770281,
-0.01435145,
-0.01149576
]

def regression_intercept_and_error(x, y):
    model = LinearRegression()
    model.fit(x, y)

    # Predicted values
    y_pred = model.predict(x)

    # Residuals
    residuals = y - y_pred

    # Degrees of freedom
    dof = len(y) - 2

    # Residual standard error
    residual_std_error = np.sqrt(np.sum(residuals**2) / dof)

    # Standard error of intercept
    x_mean = np.mean(x)
    x_diff_sq_sum = np.sum((x - x_mean) ** 2)
    intercept_std_error = residual_std_error * np.sqrt(np.sum(x ** 2) / (len(y) * x_diff_sq_sum))

    return model.intercept_, intercept_std_error

# Only using points from 3 to 6
points_to_fit = range(3, 7)

intercept_estimates = []
intercept_errors = []

for points in points_to_fit:
    x_fit = np.array(rpt2[-points:]).reshape(-1, 1)
    y_fit = np.array(Energy[-points:])
    
    intercept, intercept_error = regression_intercept_and_error(x_fit, y_fit)
    intercept_estimates.append(intercept)
    intercept_errors.append(intercept_error)
    
    # Print the intercept and its error
    print(f"Points used: {points}, Intercept: {intercept}, Error: {intercept_error}")

# Plotting intercept estimate with error bars
plt.figure(figsize=(8, 6))

plt.errorbar(points_to_fit, intercept_estimates, yerr=intercept_errors, fmt='o', color='blue', ecolor='red', capsize=5, label='exFCI')

plt.xlabel('Number of Points Used in Fit', fontsize=14)
plt.ylabel('exFCI', fontsize=14)
plt.title('exFCI errors as a Function of Number of Points 1.20Å', fontsize=16)
plt.grid(True)
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Points used: 3, Intercept: -10.915395512571179, Error: 7.3361196687229e-05
# Points used: 4, Intercept: -10.915582143876977, Error: 0.0001257582164112259
# Points used: 5, Intercept: -10.916022372045838, Error: 0.000304655716558201
# Points used: 6, Intercept: -10.916486598660434, Error: 0.0003793902166429379

# %%
####2.2

Energy = [
-8.99112903,
-9.00328449,
-9.0255385,
-9.06749294,
-9.1389182,
-9.21984622,
-9.28123279,
-9.3051788,
-9.33223367,
-9.37166455,
-9.43132193,
-9.49281661,
-9.54979436,
-9.58849224,
-9.638440350,
-9.688478640,
-9.741796190,
-9.784697590,
-9.831971650,
-9.875934400,
-9.911926260,
-9.940605140,
-9.963277080,
-9.963277090,
-9.982814390,


]
rpt2 = [
-0.277319300,
-0.280222100,
-0.286597700,
-0.289442700,
-0.274942900,
-0.249693000,
-0.223989900,
-0.221782600,
-0.215480800,
-0.203494300,
-0.182851000,
-0.162630100,
-0.145689000,
-0.134763700,
-0.121818660,
-0.108767040,
-0.094062130,
-0.083042520,
-0.070131010,
-0.057900350,
-0.047458120,
-0.038838450,
-0.031603200,
-0.031587490,
-0.024994980,

]

last_points = 10
last_points1 = 4
last_points2 = 3
last_points3 = 6
x_fit = np.array(rpt2[-last_points:]).reshape(-1, 1)
x_fit1 = np.array(rpt2[-last_points1:]).reshape(-1, 1)
x_fit2 = np.array(rpt2[-last_points2:]).reshape(-1, 1)
x_fit3 = np.array(rpt2[-last_points3:]).reshape(-1, 1)

y_fit = np.array(Energy[-last_points:])
y_fit1 = np.array(Energy[-last_points1:])
y_fit2 = np.array(Energy[-last_points2:])
y_fit3 = np.array(Energy[-last_points3:])

model = LinearRegression()
model.fit(x_fit, y_fit)
model1 = LinearRegression()
model1.fit(x_fit1, y_fit1)
model2 = LinearRegression()
model2.fit(x_fit2, y_fit2)

model3 = LinearRegression()
model3.fit(x_fit3, y_fit3)

# Calculate R^2
r_squared10 = model.score(x_fit, y_fit)
print(f'R^2;10: {r_squared10}')

r_squared4 = model1.score(x_fit1, y_fit1)
print(f'R^2;4: {r_squared4}')

r_squared3 = model2.score(x_fit2, y_fit2)
print(f'R^2;3: {r_squared3}')

r_squared6 = model3.score(x_fit3, y_fit3)
print(f'R^2;6: {r_squared6}')

# Y-value at x=0 (intercept)
y_intercept10 = model.intercept_
print(f'Y-value at x=0 10: {y_intercept10}')

y_intercept4 = model1.intercept_
print(f'Y-value at x=0 4: {y_intercept4}')

y_intercept3 = model2.intercept_
print(f'Y-value at x=0 3: {y_intercept3}')

y_intercept6 = model3.intercept_
print(f'Y-value at x=0 6: {y_intercept6}')

# Extend the fit line to min x value of -0.35
x_extended = np.linspace(-0.20, 0.0, 300).reshape(-1, 1)
y_extended = model.predict(x_extended)

x_extended1 = np.linspace(-0.20, 0.0, 300).reshape(-1, 1)
y_extended1 = model1.predict(x_extended1)

x_extended2 = np.linspace(-0.20, 0.0, 300).reshape(-1, 1)
y_extended2 = model2.predict(x_extended2)

x_extended3 = np.linspace(-0.20, 0.0, 300).reshape(-1, 1)
y_extended3 = model3.predict(x_extended3)

##non - linear plots
x_fit_quad1 = np.array(rpt2[-last_points1:])
y_fit_quad1= np.array(Energy[-last_points1:])

x_fit_quad2 = np.array(rpt2[-last_points2:])
y_fit_quad2= np.array(Energy[-last_points2:])

x_fit_quad3 = np.array(rpt2[-last_points3:])
y_fit_quad3= np.array(Energy[-last_points3:])

def model_func(rpt2, a, b, c):
    return a + (abs(c)/2) - b * rpt2 - np.sqrt((c/2)**2 + (b * rpt2)**2)

popt, _ = curve_fit(model_func, x_fit_quad1, y_fit_quad1)
a1, b1, c1 = popt

popt, _ = curve_fit(model_func, x_fit_quad2, y_fit_quad2)
a2, b2, c2 = popt

popt, _ = curve_fit(model_func, x_fit_quad3, y_fit_quad3)
a3, b3, c3 = popt


print(f'Fitted Non-linear Energies:\na4pts = {a1}\na3pts = {a2}\na6pts = {a3}')

x_extended_quad1 = np.linspace(-0.20, 0.0, 300)
y_extended_quad1 = model_func(x_extended_quad1, a1, b1, c1)

x_extended_quad2 = np.linspace(-0.20, 0.0, 300)
y_extended_quad2 = model_func(x_extended_quad2, a2, b2, c2)

x_extended_quad3 = np.linspace(-0.20, 0.0, 300)
y_extended_quad3 = model_func(x_extended_quad3, a3, b3, c3)

# Plotting Energy and exFCI against PT2
plt.figure(figsize=(6, 6))

# Plotting Energy against PT2 with the fitted line
plt.plot(rpt2, Energy, linestyle='solid', marker='o', markerfacecolor ='none', markeredgecolor = 'black', color = 'black')

#plt.plot(x_extended, y_extended, label='10', linestyle='--', color='red')

plt.plot(x_extended1, y_extended1, label='4-point extrapolation', linestyle='--', color='red')

plt.plot(x_extended2, y_extended2, label='3-point extrapolation', linestyle='--', color='green')

plt.plot(x_extended_quad1, y_extended_quad1, label='Non-Liear Fit-4pts', linestyle='--', color='magenta')

plt.plot(x_extended_quad2, y_extended_quad2, label='Non-Liear Fit-3pts', linestyle='--', color='black')

plt.plot(x_extended_quad3, y_extended_quad3, label='Non-Liear Fit-6pts', linestyle='--', color='orange')

plt.plot(x_extended3, y_extended3, label='6-point extrapolation', linestyle='--', color='blue')

plt.axhline(y=[y_intercept3], color='black', linestyle='-', marker='o', markerfacecolor ='none', markeredgecolor = 'black', linewidth = 2.0)# label=f'{y_intercept3}')

plt.xlim([-0.20, 0.00])
plt.ylim([-10.09, -9.4])
plt.xlabel('$E_{r}^{PT2}$ ($E_h$)', fontsize=20)
plt.ylabel('Variational Energy $E_{0}$ ($E_{h}$)', fontsize=20)
plt.title('H20 2.20Å', fontsize=20)
plt.legend()
plt.grid(color = 'gray', linestyle = ':', linewidth = 1.5)

plt.tight_layout()
plt.show()
# Out:
# R^2;10: 0.999011808983322
# R^2;4: 0.9996127972660737
# R^2;3: 0.9999957529333356
# R^2;6: 0.9991542803391957
# Y-value at x=0 10: -10.076295311651977
# Y-value at x=0 4: -10.059381105032685
# Y-value at x=0 3: -10.056800011719293
# Y-value at x=0 6: -10.065899972743651
# Fitted Non-linear Energies:
# a4pts = -10.059383075427162
# a3pts = -10.056800682618968
# a6pts = -10.0659026495819
# /opt/anaconda3/lib/python3.11/site-packages/scipy/optimize/_minpack_py.py:1010: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Provided data
Energy = [-10.211488490,
-10.223282730,
-10.241731220,
-10.262028350,
-10.290284230,
-10.322977080,
-10.351125870,
-10.379534020,
-10.416477840,
-10.452626290,
-10.483436740,
-10.512395280,
-10.533995120,
-10.552550620,
-10.563837660,
-10.575058050,
-10.587312270,
-10.599977200,
-10.612231870,
-10.624005980,
-10.634842730,
-10.644479400,
-10.652828510
]
rpt2 = [
-2.540703E-01,
-2.537797E-01,
-2.479393E-01,
-2.434109E-01,
-2.283694E-01,
-2.074752E-01,
-1.924169E-01,
-1.767663E-01,
-1.552240E-01,
-1.353536E-01,
-1.166979E-01,
-9.610532E-02,
-8.010348E-02,
-6.827138E-02,
-6.397364E-02,
-6.076634E-02,
-5.661752E-02,
-5.118298E-02,
-4.535084E-02,
-3.966712E-02,
-3.430490E-02,
-2.939425E-02,
-2.519441E-02
]

# Function to calculate intercept and its standard error
def regression_intercept_and_error(x, y):
    model = LinearRegression()
    model.fit(x, y)

    # Predicted values
    y_pred = model.predict(x)

    # Residuals
    residuals = y - y_pred

    # Degrees of freedom
    dof = len(y) - 2

    # Residual standard error
    residual_std_error = np.sqrt(np.sum(residuals**2) / dof)

    # Standard error of intercept
    x_mean = np.mean(x)
    x_diff_sq_sum = np.sum((x - x_mean) ** 2)
    intercept_std_error = residual_std_error * np.sqrt(np.sum(x ** 2) / (len(y) * x_diff_sq_sum))

    return model.intercept_, intercept_std_error

# Only using points from 3 to 6
points_to_fit = range(3, 7)

intercept_estimates = []
intercept_errors = []

for points in points_to_fit:
    x_fit = np.array(rpt2[-points:]).reshape(-1, 1)
    y_fit = np.array(Energy[-points:])

    intercept, intercept_error = regression_intercept_and_error(x_fit, y_fit)
    intercept_estimates.append(intercept)
    intercept_errors.append(intercept_error)

# Plotting intercept estimate with error bars
plt.figure(figsize=(8, 6))

plt.errorbar(points_to_fit, intercept_estimates, yerr=intercept_errors, fmt='o', color='blue', ecolor='red', capsize=5, label='exFCI')

plt.xlabel('Number of Points Used in Fit', fontsize=14)
plt.ylabel('exFCI', fontsize=14)
plt.title('exFCI as a Function of Number of Points for 2.2A', fontsize=16)
plt.grid(True)
plt.legend()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit

##2.0
Energy = [
-9.26249559,
-9.27402197,
-9.29123429,
-9.31884151,
-9.3727868,
-9.43214675,
-9.49025675,
-9.53051089,
-9.54707136,
-9.5793969,
-9.61175699,
-9.66198191,
-9.71172585,
-9.75693532,
-9.78746776,
-9.82311135,
-9.85939065,
-9.89919931,
-9.93153972,
-9.95894304,
-9.98835619,
-9.98835619,
-10.01204421,
-10.01204421,
-10.03192974,
-10.04891131
]
rpt2 = [
-2.7439440E-01,
-2.7617850E-01,
-2.8115120E-01,
-2.8049150E-01,
-2.6279230E-01,
-2.4613170E-01,
-2.2046330E-01,
-2.0493090E-01,
-2.0261510E-01,
-1.9220520E-01,
-1.7991570E-01,
-1.6050340E-01,
-1.4420740E-01,
-1.2764900E-01,
-1.1770070E-01,
-1.0591420E-01,
-9.3997130E-02,
-8.0664640E-02,
-7.0062840E-02,
-6.1061290E-02,
-5.1121050E-02,
-5.1119870E-02,
-4.3341630E-02,
-4.3292120E-02,
-3.6535620E-02,
-3.0941970E-02
]

pt2=[
-0.571800,
-0.559158,
-0.536987,
-0.490073,
-0.392381,
-0.333573,
-0.275889,
-0.246833,
-0.241534,
-0.224045,
-0.205366,
-0.178362,
-0.157190,
-0.136813,
-0.124972,
-0.111358,
-0.097981,
-0.083375,
-0.071980,
-0.062440,
-0.052034,
-0.043970,
-0.036966,
-0.031242,

]


# Define the model function
def model_func(pt2, a, b, c):
    return a + (abs(c)/2) - b * pt2 - np.sqrt((c/2)**2 + (b * pt2)**2)

a_values = []
a_errors = []

for last_points in range(3, 24):
    x_fit = np.array(pt2[-last_points:])
    y_fit = np.array(Energy[-last_points:])
    
    # Perform the curve fitting
    popt, pcov = curve_fit(model_func, x_fit, y_fit)
    a, b, c = popt
    a_values.append(a)  
    
    a_err = np.sqrt(pcov[0, 0])  #diagonal element
    a_errors.append(a_err) 
    
    print(f"Fitted parameters for last {last_points} points: a = {a:.6f} ± {a_err:.6f}, b = {b:.6f}, c = {c:.6f}")

plt.figure(figsize=(8, 6))
plt.errorbar(range(3, 24), a_values, yerr=a_errors, fmt='o', linestyle='-', color='blue', ecolor='red', capsize=5)
plt.xlabel('Number of Last Points Used for Fitting', fontsize=14)
plt.ylabel('Fitted Parameter a', fontsize=14)
plt.title('Fitted Parameter a with Standard Errors vs. Number of Last Points', fontsize=16)
plt.grid(True)
plt.show()
# Out:
# Fitted parameters for last 3 points: a = -10.153654 ± inf, b = 3.685688, c = -1.263827
# Fitted parameters for last 4 points: a = -10.101367 ± inf, b = 1.830262, c = 1640.661424
# Fitted parameters for last 5 points: a = -10.287972 ± 0.688827, b = 15.059171, c = -0.728975
# Fitted parameters for last 6 points: a = -10.086779 ± inf, b = 1.470180, c = 4356.334691
# Fitted parameters for last 7 points: a = -10.116956 ± 0.049528, b = 2.652180, c = 0.643608
# Fitted parameters for last 8 points: a = -10.093349 ± 0.008686, b = 1.614075, c = 1175.561455
# Fitted parameters for last 9 points: a = -10.098765 ± 0.007925, b = 1.720780, c = 6934.426867
# Fitted parameters for last 10 points: a = -10.106306 ± 0.008654, b = 1.860073, c = 3905.120461
# Fitted parameters for last 11 points: a = -10.113705 ± 0.010307, b = 1.989082, c = 17442.351677
# Fitted parameters for last 12 points: a = -10.116969 ± 0.008962, b = 2.041344, c = 5865.394417
# ...
